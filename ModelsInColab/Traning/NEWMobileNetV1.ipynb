# %%
# Mount Drive (Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, time, json, pathlib, itertools
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

# ============================================================
# CONFIG (EDIT ONLY HERE)
# ============================================================
DATASET_DIR = "/content/drive/MyDrive/ImageClassification/TrashData"
OUT_DIR     = "/content/drive/MyDrive/ImageClassification/OUT_MobileNetV1"
IMG_SIZE    = (224, 224)

LR_HEAD = 1e-3
LR_FINE = 1e-5

BATCH_PER_REPLICA = 32
SEED             = 42
KFOLDS           = 3
EPOCHS_HEAD      = 5
EPOCHS_FINE      = 10
CV_PATIENCE      = 4
FINAL_PATIENCE   = 5

WARMUP_RUNS      = 7
BENCH_RUNS       = 10
REP_BATCHES      = 15

TEST_SIZE        = 0.30
FINAL_VAL_SIZE   = 0.15
FINE_TUNE_RATIO  = 0.8

FOCAL_GAMMA      = 2.0
FOCAL_ALPHA      = 1.0
REDUCE_LR_FACTOR = 0.5

AUTOTUNE = tf.data.AUTOTUNE

# ============================================================
# OUTPUT PATHS
# ============================================================
os.makedirs(OUT_DIR, exist_ok=True)
PLOTS_DIR = os.path.join(OUT_DIR, "plots")
os.makedirs(PLOTS_DIR, exist_ok=True)

MODEL_PATH       = os.path.join(OUT_DIR, "best.keras")
CLEAN_MODEL_PATH = os.path.join(OUT_DIR, "best_noopt.keras")
METRICS_PATH     = os.path.join(OUT_DIR, "metrics.json")

LOSS_PNG = os.path.join(PLOTS_DIR, "loss_train_vs_val.png")
ACC_PNG  = os.path.join(PLOTS_DIR, "acc_train_vs_val.png")
CM_PNG   = os.path.join(PLOTS_DIR, "confusion_matrix.png")

TFLITE_FP32_PATH = os.path.join(OUT_DIR, "best_fp32.tflite")
TFLITE_DRQ_PATH  = os.path.join(OUT_DIR, "best_dynamic_range.tflite")
TFLITE_INT8_PATH = os.path.join(OUT_DIR, "best_int8.tflite")
LABELS_TXT       = os.path.join(OUT_DIR, "labels.txt")

np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# ============================================================
# TPU / STRATEGY INIT
# ============================================================
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
    print("TPU:", tpu.master())
except Exception as e:
    strategy = tf.distribute.get_strategy()
    print("TPU not used. Fallback strategy. Reason:", e)

print("Strategy:", type(strategy).__name__)
print("Replicas:", strategy.num_replicas_in_sync)

NUM_REPLICAS = strategy.num_replicas_in_sync
GLOBAL_BATCH = BATCH_PER_REPLICA * NUM_REPLICAS
print("GLOBAL_BATCH:", GLOBAL_BATCH)
# Out:
# TPU not used. Fallback strategy. Reason: Please provide a TPU Name to connect to.
# Strategy: _DefaultDistributionStrategy
# Replicas: 1
# GLOBAL_BATCH: 32

# %%
# ============================================================
# DATA HELPERS
# ============================================================
def list_files(dataset_dir):
    p = pathlib.Path(dataset_dir)
    classes = sorted([d.name for d in p.iterdir() if d.is_dir()])
    paths, labels = [], []
    for i, c in enumerate(classes):
        for x in (p / c).glob("*"):
            if x.suffix.lower() in [".jpg", ".jpeg", ".png"]:
                paths.append(str(x))
                labels.append(i)
    return np.array(paths), np.array(labels), classes

def decode_resize(path, label):
    img_bytes = tf.io.read_file(path)
    is_jpeg = tf.strings.regex_full_match(tf.strings.lower(path), ".*\\.jpe?g")
    img = tf.cond(
        is_jpeg,
        lambda: tf.image.decode_jpeg(img_bytes, channels=3),
        lambda: tf.image.decode_png(img_bytes, channels=3),
    )
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32)
    img = preprocess_input(img)   # MobileNetV1 preprocess
    return img, label

def augment(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, 0.08)
    img = tf.image.random_contrast(img, 0.9, 1.1)
    k = tf.random.uniform([], 0, 4, dtype=tf.int32)
    img = tf.image.rot90(img, k)
    return img, label

def make_ds(paths, labels, train=False):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    if train:
        ds = ds.shuffle(buffer_size=len(paths), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(decode_resize, num_parallel_calls=AUTOTUNE)
    if train:
        ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(GLOBAL_BATCH, drop_remainder=train).prefetch(AUTOTUNE)
    return ds

def oversample(paths, labels):
    rng = np.random.RandomState(SEED)
    cls, cnt = np.unique(labels, return_counts=True)
    m = cnt.max()
    new_p, new_y = [], []
    for c in cls:
        idx = np.where(labels == c)[0]
        chosen = rng.choice(idx, size=m, replace=True)
        new_p.extend(paths[chosen].tolist())
        new_y.extend([c] * m)
    perm = rng.permutation(len(new_p))
    return np.array(new_p)[perm], np.array(new_y)[perm]

# %%
# ============================================================
# MODEL
# ============================================================
def focal_loss(num_classes, gamma=FOCAL_GAMMA, alpha=FOCAL_ALPHA):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.int32)
        y_one = tf.one_hot(y_true, depth=num_classes)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        ce = -y_one * tf.math.log(y_pred)
        w = alpha * tf.math.pow(1 - y_pred, gamma)
        return tf.reduce_sum(w * ce, axis=1)
    return loss

def build_model(num_classes):
    base = MobileNet(
        input_shape=IMG_SIZE + (3,),
        include_top=False,
        weights="imagenet",
        alpha=1.0   # MobileNetV1 width multiplier (1.0 = full)
    )
    base.trainable = False

    inp = layers.Input(shape=IMG_SIZE + (3,))
    x = base(inp, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    out = layers.Dense(num_classes, activation="softmax")(x)
    return models.Model(inp, out), base

def compile_model(model, num_classes, lr):
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss=focal_loss(num_classes),
        metrics=["accuracy"],
    )

def fine_tune(base, ratio=FINE_TUNE_RATIO):
    base.trainable = True
    n = len(base.layers)
    fine_at = int(n * ratio)
    for i, layer in enumerate(base.layers):
        layer.trainable = (i >= fine_at)

# %%
# ============================================================
# EVAL
# ============================================================
def eval_metrics(model, ds, class_names):
    y_true, y_pred = [], []
    for x, y in ds:
        p = model.predict(x, verbose=0)
        y_true.extend(y.numpy().tolist())
        y_pred.extend(np.argmax(p, axis=1).tolist())

    rep = classification_report(
        y_true, y_pred, target_names=class_names, output_dict=True, zero_division=0
    )
    acc = rep["accuracy"]
    prec = np.mean([rep[c]["precision"] for c in class_names])
    rec  = np.mean([rep[c]["recall"] for c in class_names])
    f1   = np.mean([rep[c]["f1-score"] for c in class_names])
    return acc, prec, rec, f1

def get_preds(model, ds):
    y_true, y_pred = [], []
    for x, y in ds:
        p = model.predict(x, verbose=0)
        y_true.extend(y.numpy().tolist())
        y_pred.extend(np.argmax(p, axis=1).tolist())
    return np.array(y_true), np.array(y_pred)

# ============================================================
# SAVE 2 GRAPHS
# ============================================================
def save_train_val_plots(h1, h2, loss_path, acc_path):
    def cat(k):
        return list(h1.history.get(k, [])) + list(h2.history.get(k, []))

    tr_loss = cat("loss")
    va_loss = cat("val_loss")
    tr_acc  = cat("accuracy")
    va_acc  = cat("val_accuracy")
    epochs  = np.arange(1, len(tr_loss) + 1)

    plt.figure()
    plt.plot(epochs, tr_loss, label="train_loss")
    plt.plot(epochs, va_loss, label="val_loss")
    plt.xlabel("Epoch"); plt.ylabel("Loss")
    plt.title("Training vs Validation Loss")
    plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(loss_path, dpi=200)
    plt.close()

    plt.figure()
    plt.plot(epochs, tr_acc, label="train_acc")
    plt.plot(epochs, va_acc, label="val_acc")
    plt.xlabel("Epoch"); plt.ylabel("Accuracy")
    plt.title("Training vs Validation Accuracy")
    plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(acc_path, dpi=200)
    plt.close()

# ============================================================
# CONFUSION MATRIX SAVE
# (blue cmap, text always black)
# ============================================================
def save_confusion_matrix_png(y_true, y_pred, class_names, out_path, normalize=False):
    cm = confusion_matrix(y_true, y_pred, labels=np.arange(len(class_names)))

    if normalize:
        cm = cm.astype("float32") / np.maximum(cm.sum(axis=1, keepdims=True), 1e-9)

    plt.figure(figsize=(8, 8))

    vmax = 1.0 if normalize else cm.max()
    plt.imshow(cm, cmap="Blues", vmin=0.0, vmax=vmax)

    plt.title("Confusion Matrix" + (" (Normalized)" if normalize else ""))
    plt.colorbar()

    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45, ha="right")
    plt.yticks(tick_marks, class_names)

    fmt = ".2f" if normalize else "d"

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(
            j, i, format(cm[i, j], fmt),
            ha="center",
            va="center",
            color="black"
        )

    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.tight_layout()
    plt.savefig(out_path, dpi=200)
    plt.close()

# %%
# ============================================================
# RUN
# ============================================================
paths, labels, class_names = list_files(DATASET_DIR)
num_classes = len(class_names)
print("Classes:", class_names)
print("Num classes:", num_classes)

# Split: Train vs Test (TEST never touched in CV/training decisions)
train_p, test_p, train_y, test_y = train_test_split(
    paths, labels, test_size=TEST_SIZE, random_state=SEED, stratify=labels
)

# -----------------------
# CV on TRAIN only
# -----------------------
skf = StratifiedKFold(n_splits=KFOLDS, shuffle=True, random_state=SEED)
cv_acc = []

for fold, (tr, va) in enumerate(skf.split(train_p, train_y), start=1):
    tr_p, tr_l = train_p[tr], train_y[tr]
    va_p, va_l = train_p[va], train_y[va]

    tr_p2, tr_l2 = oversample(tr_p, tr_l)
    tr_ds = make_ds(tr_p2, tr_l2, train=True)
    va_ds = make_ds(va_p, va_l, train=False)

    with strategy.scope():
        model, base = build_model(num_classes)
        compile_model(model, num_classes, LR_HEAD)

    cb_cv = [
        callbacks.EarlyStopping(monitor="val_loss", patience=CV_PATIENCE, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(monitor="val_loss", factor=REDUCE_LR_FACTOR, patience=1),
    ]

    model.fit(tr_ds, validation_data=va_ds, epochs=EPOCHS_HEAD, verbose=1, callbacks=cb_cv)

    with strategy.scope():
        fine_tune(base, ratio=FINE_TUNE_RATIO)
        compile_model(model, num_classes, LR_FINE)

    model.fit(tr_ds, validation_data=va_ds, epochs=EPOCHS_FINE, verbose=1, callbacks=cb_cv)

    acc, _, _, _ = eval_metrics(model, va_ds, class_names)
    cv_acc.append(acc)
    print(f"Fold {fold} val accuracy: {acc:.4f}")

cv_mean, cv_std = float(np.mean(cv_acc)), float(np.std(cv_acc))
print(f"\nCV Accuracy (mean ± std): {cv_mean:.4f} ± {cv_std:.4f}")

# -----------------------
# Final Train/Val split from TRAIN only
# -----------------------
final_tr_p, final_va_p, final_tr_y, final_va_y = train_test_split(
    train_p, train_y, test_size=FINAL_VAL_SIZE, random_state=SEED, stratify=train_y
)

final_tr_p2, final_tr_y2 = oversample(final_tr_p, final_tr_y)
final_tr_ds = make_ds(final_tr_p2, final_tr_y2, train=True)
final_va_ds = make_ds(final_va_p, final_va_y, train=False)
test_ds     = make_ds(test_p, test_y, train=False)

# -----------------------
# Final training + checkpoint
# -----------------------
with strategy.scope():
    model, base = build_model(num_classes)
    compile_model(model, num_classes, LR_HEAD)

ckpt = callbacks.ModelCheckpoint(MODEL_PATH, monitor="val_accuracy", save_best_only=True, verbose=1)
cb_final = [
    ckpt,
    callbacks.EarlyStopping(monitor="val_loss", patience=FINAL_PATIENCE, restore_best_weights=True),
    callbacks.ReduceLROnPlateau(monitor="val_loss", factor=REDUCE_LR_FACTOR, patience=1),
]

h1 = model.fit(final_tr_ds, validation_data=final_va_ds, epochs=EPOCHS_HEAD, verbose=1, callbacks=cb_final)

with strategy.scope():
    fine_tune(base, ratio=FINE_TUNE_RATIO)
    compile_model(model, num_classes, LR_FINE)

h2 = model.fit(final_tr_ds, validation_data=final_va_ds, epochs=EPOCHS_FINE, verbose=1, callbacks=cb_final)

# Load best + save clean model (no optimizer)
best = tf.keras.models.load_model(MODEL_PATH, compile=False)
best.save(CLEAN_MODEL_PATH, include_optimizer=False)

# Save plots
save_train_val_plots(h1, h2, LOSS_PNG, ACC_PNG)

# Test evaluation
test_acc, test_prec, test_rec, test_f1 = eval_metrics(best, test_ds, class_names)

# Confusion matrix (normalized)
y_true, y_pred = get_preds(best, test_ds)
save_confusion_matrix_png(y_true, y_pred, class_names, CM_PNG, normalize=True)

# Model size
train_model_size_mb = os.path.getsize(MODEL_PATH) / (1024 * 1024)
clean_model_size_mb = os.path.getsize(CLEAN_MODEL_PATH) / (1024 * 1024)
# Out:
# Classes: ['Biological', 'Metal', 'Paper', 'Plastic']
# Num classes: 4
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 425s 7s/step - accuracy: 0.4425 - loss: 1.1598 - val_accuracy: 0.8387 - val_loss: 0.1879 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 0.7727 - loss: 0.3342 - val_accuracy: 0.8935 - val_loss: 0.1293 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 161ms/step - accuracy: 0.8228 - loss: 0.2913 - val_accuracy: 0.9118 - val_loss: 0.1193 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.8439 - loss: 0.2201 - val_accuracy: 0.9118 - val_loss: 0.1086 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 198ms/step - accuracy: 0.8712 - loss: 0.1633 - val_accuracy: 0.9172 - val_loss: 0.0999 - learning_rate: 0.0010
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 26s 259ms/step - accuracy: 0.8607 - loss: 0.2290 - val_accuracy: 0.9194 - val_loss: 0.1042 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 155ms/step - accuracy: 0.8509 - loss: 0.2212 - val_accuracy: 0.9151 - val_loss: 0.1082 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.8684 - loss: 0.1861 - val_accuracy: 0.9151 - val_loss: 0.1094 - learning_rate: 5.0000e-06
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 185ms/step - accuracy: 0.8776 - loss: 0.1737 - val_accuracy: 0.9183 - val_loss: 0.1110 - learning_rate: 2.5000e-06
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.9012 - loss: 0.1336 - val_accuracy: 0.9161 - val_loss: 0.1127 - learning_rate: 1.2500e-06
# Fold 1 val accuracy: 0.9194
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - accuracy: 0.4606 - loss: 1.0772 - val_accuracy: 0.8398 - val_loss: 0.1929 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - accuracy: 0.7631 - loss: 0.3697 - val_accuracy: 0.8645 - val_loss: 0.1707 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 161ms/step - accuracy: 0.8324 - loss: 0.2593 - val_accuracy: 0.8978 - val_loss: 0.1422 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - accuracy: 0.8686 - loss: 0.1771 - val_accuracy: 0.9054 - val_loss: 0.1193 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.8874 - loss: 0.1424 - val_accuracy: 0.9011 - val_loss: 0.1328 - learning_rate: 0.0010
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 26s 269ms/step - accuracy: 0.8661 - loss: 0.2330 - val_accuracy: 0.9086 - val_loss: 0.1299 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.8544 - loss: 0.2309 - val_accuracy: 0.9075 - val_loss: 0.1261 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 158ms/step - accuracy: 0.8541 - loss: 0.2021 - val_accuracy: 0.9097 - val_loss: 0.1262 - learning_rate: 1.0000e-05
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.8810 - loss: 0.1562 - val_accuracy: 0.9097 - val_loss: 0.1236 - learning_rate: 5.0000e-06
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.8908 - loss: 0.1563 - val_accuracy: 0.9140 - val_loss: 0.1238 - learning_rate: 5.0000e-06
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 202ms/step - accuracy: 0.8789 - loss: 0.1499 - val_accuracy: 0.9151 - val_loss: 0.1238 - learning_rate: 2.5000e-06
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 199ms/step - accuracy: 0.8950 - loss: 0.1360 - val_accuracy: 0.9151 - val_loss: 0.1228 - learning_rate: 1.2500e-06
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 156ms/step - accuracy: 0.8960 - loss: 0.1731 - val_accuracy: 0.9140 - val_loss: 0.1219 - learning_rate: 1.2500e-06
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.8810 - loss: 0.1583 - val_accuracy: 0.9118 - val_loss: 0.1218 - learning_rate: 1.2500e-06
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.8711 - loss: 0.1719 - val_accuracy: 0.9118 - val_loss: 0.1217 - learning_rate: 6.2500e-07
# Fold 2 val accuracy: 0.9118
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 37s 560ms/step - accuracy: 0.4038 - loss: 1.2640 - val_accuracy: 0.8473 - val_loss: 0.1845 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 157ms/step - accuracy: 0.7329 - loss: 0.4079 - val_accuracy: 0.9108 - val_loss: 0.1145 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 167ms/step - accuracy: 0.7968 - loss: 0.3026 - val_accuracy: 0.9118 - val_loss: 0.1131 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.8433 - loss: 0.2298 - val_accuracy: 0.9301 - val_loss: 0.1009 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 153ms/step - accuracy: 0.8604 - loss: 0.1896 - val_accuracy: 0.9258 - val_loss: 0.0986 - learning_rate: 0.0010
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 24s 254ms/step - accuracy: 0.8179 - loss: 0.2580 - val_accuracy: 0.9312 - val_loss: 0.1012 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - accuracy: 0.8596 - loss: 0.2097 - val_accuracy: 0.9258 - val_loss: 0.1026 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.8720 - loss: 0.1980 - val_accuracy: 0.9269 - val_loss: 0.0991 - learning_rate: 5.0000e-06
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 209ms/step - accuracy: 0.8643 - loss: 0.2065 - val_accuracy: 0.9290 - val_loss: 0.0972 - learning_rate: 5.0000e-06
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.8762 - loss: 0.1953 - val_accuracy: 0.9290 - val_loss: 0.0964 - learning_rate: 5.0000e-06
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 13s 215ms/step - accuracy: 0.8641 - loss: 0.1855 - val_accuracy: 0.9280 - val_loss: 0.0959 - learning_rate: 5.0000e-06
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.8820 - loss: 0.1537 - val_accuracy: 0.9301 - val_loss: 0.0934 - learning_rate: 5.0000e-06
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - accuracy: 0.8888 - loss: 0.1762 - val_accuracy: 0.9280 - val_loss: 0.0935 - learning_rate: 5.0000e-06
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.9041 - loss: 0.1344 - val_accuracy: 0.9312 - val_loss: 0.0925 - learning_rate: 2.5000e-06
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.8904 - loss: 0.1722 - val_accuracy: 0.9355 - val_loss: 0.0918 - learning_rate: 2.5000e-06
# Fold 3 val accuracy: 0.9355
#
# CV Accuracy (mean ± std): 0.9222 ± 0.0099
# Epoch 1/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4236 - loss: 1.2137
# Epoch 1: val_accuracy improved from -inf to 0.87589, saving model to /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 28s 308ms/step - accuracy: 0.4257 - loss: 1.2076 - val_accuracy: 0.8759 - val_loss: 0.1471 - learning_rate: 0.0010
# Epoch 2/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7900 - loss: 0.3344
# Epoch 2: val_accuracy improved from 0.87589 to 0.90931, saving model to /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 26s 140ms/step - accuracy: 0.7904 - loss: 0.3336 - val_accuracy: 0.9093 - val_loss: 0.1210 - learning_rate: 0.0010
# Epoch 3/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8541 - loss: 0.2097
# Epoch 3: val_accuracy did not improve from 0.90931
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8541 - loss: 0.2096 - val_accuracy: 0.9021 - val_loss: 0.1286 - learning_rate: 0.0010
# Epoch 4/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8616 - loss: 0.1923
# Epoch 4: val_accuracy improved from 0.90931 to 0.91169, saving model to /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - accuracy: 0.8617 - loss: 0.1920 - val_accuracy: 0.9117 - val_loss: 0.1090 - learning_rate: 5.0000e-04
# Epoch 5/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8672 - loss: 0.1944
# Epoch 5: val_accuracy did not improve from 0.91169
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.8673 - loss: 0.1941 - val_accuracy: 0.9117 - val_loss: 0.1072 - learning_rate: 5.0000e-04
# Epoch 1/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.8555 - loss: 0.2206
# Epoch 1: val_accuracy improved from 0.91169 to 0.92124, saving model to /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 25s 205ms/step - accuracy: 0.8555 - loss: 0.2206 - val_accuracy: 0.9212 - val_loss: 0.1045 - learning_rate: 1.0000e-05
# Epoch 2/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8620 - loss: 0.2098
# Epoch 2: val_accuracy improved from 0.92124 to 0.92601, saving model to /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.8621 - loss: 0.2098 - val_accuracy: 0.9260 - val_loss: 0.1018 - learning_rate: 1.0000e-05
# Epoch 3/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8728 - loss: 0.1837
# Epoch 3: val_accuracy improved from 0.92601 to 0.93079, saving model to /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 157ms/step - accuracy: 0.8729 - loss: 0.1838 - val_accuracy: 0.9308 - val_loss: 0.0981 - learning_rate: 1.0000e-05
# Epoch 4/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8788 - loss: 0.1561
# Epoch 4: val_accuracy did not improve from 0.93079
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.8790 - loss: 0.1561 - val_accuracy: 0.9308 - val_loss: 0.0970 - learning_rate: 1.0000e-05
# Epoch 5/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9056 - loss: 0.1473
# Epoch 5: val_accuracy improved from 0.93079 to 0.93317, saving model to /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.9054 - loss: 0.1473 - val_accuracy: 0.9332 - val_loss: 0.0963 - learning_rate: 1.0000e-05
# Epoch 6/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8992 - loss: 0.1439
# Epoch 6: val_accuracy did not improve from 0.93317
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 161ms/step - accuracy: 0.8992 - loss: 0.1439 - val_accuracy: 0.9332 - val_loss: 0.0950 - learning_rate: 1.0000e-05
# Epoch 7/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8823 - loss: 0.1495
# Epoch 7: val_accuracy improved from 0.93317 to 0.93795, saving model to /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 11s 146ms/step - accuracy: 0.8825 - loss: 0.1493 - val_accuracy: 0.9379 - val_loss: 0.0946 - learning_rate: 1.0000e-05
# Epoch 8/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9052 - loss: 0.1575
# Epoch 8: val_accuracy did not improve from 0.93795
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9053 - loss: 0.1571 - val_accuracy: 0.9356 - val_loss: 0.0943 - learning_rate: 1.0000e-05
# Epoch 9/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8958 - loss: 0.1483
# Epoch 9: val_accuracy improved from 0.93795 to 0.94033, saving model to /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 10s 131ms/step - accuracy: 0.8959 - loss: 0.1481 - val_accuracy: 0.9403 - val_loss: 0.0940 - learning_rate: 1.0000e-05
# Epoch 10/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8997 - loss: 0.1177
# Epoch 10: val_accuracy did not improve from 0.94033
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 11s 143ms/step - accuracy: 0.8997 - loss: 0.1178 - val_accuracy: 0.9379 - val_loss: 0.0934 - learning_rate: 1.0000e-05

# %%
# ============================================================
# BENCHMARK
# ============================================================
def benchmark_warm(model, warmup=WARMUP_RUNS, runs=BENCH_RUNS):
    x1 = np.random.rand(1, *IMG_SIZE, 3).astype("float32")
    xb = np.random.rand(GLOBAL_BATCH, *IMG_SIZE, 3).astype("float32")

    for _ in range(warmup):
        _ = model.predict(x1, verbose=0)

    t0 = time.time()
    for _ in range(runs):
        _ = model.predict(x1, verbose=0)
    single_ms = ((time.time() - t0) / runs) * 1000

    for _ in range(warmup):
        _ = model.predict(xb, verbose=0)

    t0 = time.time()
    for _ in range(runs):
        _ = model.predict(xb, verbose=0)
    total = time.time() - t0

    thr = (GLOBAL_BATCH * runs) / total
    eff_ms = 1000.0 / thr
    return single_ms, thr, eff_ms

single_ms, thr, eff_ms = benchmark_warm(best, warmup=WARMUP_RUNS, runs=BENCH_RUNS)
params = int(best.count_params())

out = {
    "model": "MobileNetV1",
    "classes": class_names,
    "strategy": type(strategy).__name__,
    "replicas": int(NUM_REPLICAS),
    "global_batch": int(GLOBAL_BATCH),
    "cv_accuracy_mean": cv_mean,
    "cv_accuracy_std": cv_std,
    "test_accuracy": float(test_acc),
    "precision_macro": float(test_prec),
    "recall_macro": float(test_rec),
    "f1_macro": float(test_f1),
    "parameters": params,
    "model_size_mb_training_checkpoint": float(train_model_size_mb),
    "model_size_mb_clean_inference": float(clean_model_size_mb),
    "single_image_latency_ms_after_warmup": float(single_ms),
    "throughput_images_per_sec": float(thr),
    "effective_ms_per_image_from_throughput": float(eff_ms),
    "loss_plot_path": LOSS_PNG,
    "accuracy_plot_path": ACC_PNG,
    "confusion_matrix_plot_path": CM_PNG,
}

with open(METRICS_PATH, "w") as f:
    json.dump(out, f, indent=2)

print("\nSaved training checkpoint:", MODEL_PATH)
print("Saved clean inference model:", CLEAN_MODEL_PATH)
print("Saved loss plot:", LOSS_PNG)
print("Saved accuracy plot:", ACC_PNG)
print("Saved confusion matrix:", CM_PNG)
print("Metrics:", METRICS_PATH)
# Out:
# Saved training checkpoint: /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best.keras
# Saved clean inference model: /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best_noopt.keras
# Saved loss plot: /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/plots/loss_train_vs_val.png
# Saved accuracy plot: /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/plots/acc_train_vs_val.png
# Saved confusion matrix: /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/plots/confusion_matrix.png
# Metrics: /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/metrics.json

# %%
# ============================================================
# TFLite EXPORT
# ============================================================
with open(LABELS_TXT, "w") as f:
    for name in class_names:
        f.write(name + "\n")
print("Saved labels:", LABELS_TXT)

clean = tf.keras.models.load_model(CLEAN_MODEL_PATH, compile=False)

# FP32
converter = tf.lite.TFLiteConverter.from_keras_model(clean)
tflite_fp32 = converter.convert()
with open(TFLITE_FP32_PATH, "wb") as f:
    f.write(tflite_fp32)
print("Saved TFLite FP32:", TFLITE_FP32_PATH)

# Dynamic Range Quant
converter = tf.lite.TFLiteConverter.from_keras_model(clean)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_drq = converter.convert()
with open(TFLITE_DRQ_PATH, "wb") as f:
    f.write(tflite_drq)
print("Saved TFLite Dynamic Range:", TFLITE_DRQ_PATH)

# INT8
def rep_data_gen():
    for x, _ in final_tr_ds.take(REP_BATCHES):
        yield [tf.cast(x, tf.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(clean)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = rep_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

try:
    tflite_int8 = converter.convert()
    with open(TFLITE_INT8_PATH, "wb") as f:
        f.write(tflite_int8)
    print("Saved TFLite INT8:", TFLITE_INT8_PATH)
except Exception as e:
    print("INT8 conversion failed. Reason:", e)
    print("Tip: remove int8 input/output lines for hybrid quantization and try again.")
# Out:
# Saved labels: /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/labels.txt
# Saved artifact at '/tmp/tmptl6dvnuq'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   138518054199440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054199248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054199632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054200016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054197136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054199056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054197520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054200208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054195600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054200976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054196560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054196176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054207120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054207312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030745680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030745872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138521074513104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518031434768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518031434576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518102839120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518102836240: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite FP32: /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best_fp32.tflite
# Saved artifact at '/tmp/tmps9uh7gw_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   138518054199440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054199248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054199632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054200016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054197136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054199056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054197520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054200208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054195600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054200976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054196560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054196176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054207120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054207312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030745680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030745872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138521074513104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518031434768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518031434576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518102839120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518102836240: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite Dynamic Range: /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best_dynamic_range.tflite
# Saved artifact at '/tmp/tmpevjsy5xg'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   138518054199440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054199248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054199632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054200016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054197136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054199056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054197520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054200208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054195600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054198672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054201168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054200976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054196560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054202704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054196176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054203472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054207120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054205392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054206352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054204432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518054207312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030745680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030745872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030746256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030747408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030748368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030749328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030750288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030751248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030752208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030753168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030754128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030755088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030756048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138521074513104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030759504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030757968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030758928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518031434768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518031434576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030761808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518030760848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518102839120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138518102836240: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Saved TFLite INT8: /content/drive/MyDrive/ImageClassification/OUT_MobileNetV1/best_int8.tflite
