# %%
# Mount Drive (Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, time, json, pathlib, itertools
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

# ============================================================
# CONFIG (EDIT ONLY HERE)
# ============================================================
DATASET_DIR = "/content/drive/MyDrive/ImageClassification/TrashData"
OUT_DIR     = "/content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0"
IMG_SIZE    = (224, 224)

LR_HEAD = 1e-3
LR_FINE = 1e-5

BATCH_PER_REPLICA = 32 #32
SEED             = 42
KFOLDS           = 3
EPOCHS_HEAD      = 5
EPOCHS_FINE      = 10
CV_PATIENCE      = 4
FINAL_PATIENCE   = 5

WARMUP_RUNS      = 7
BENCH_RUNS       = 10
REP_BATCHES      = 15

TEST_SIZE        = 0.30
FINAL_VAL_SIZE   = 0.15
FINE_TUNE_RATIO  = 0.8

FOCAL_GAMMA      = 2.0
FOCAL_ALPHA      = 1.0
REDUCE_LR_FACTOR = 0.5

AUTOTUNE = tf.data.AUTOTUNE

# ============================================================
# OUTPUT PATHS
# ============================================================
os.makedirs(OUT_DIR, exist_ok=True)
PLOTS_DIR = os.path.join(OUT_DIR, "plots")
os.makedirs(PLOTS_DIR, exist_ok=True)

MODEL_PATH       = os.path.join(OUT_DIR, "best.keras")
CLEAN_MODEL_PATH = os.path.join(OUT_DIR, "best_noopt.keras")
METRICS_PATH     = os.path.join(OUT_DIR, "metrics.json")

LOSS_PNG = os.path.join(PLOTS_DIR, "loss_train_vs_val.png")
ACC_PNG  = os.path.join(PLOTS_DIR, "acc_train_vs_val.png")
CM_PNG   = os.path.join(PLOTS_DIR, "confusion_matrix.png")

TFLITE_FP32_PATH = os.path.join(OUT_DIR, "best_fp32.tflite")
TFLITE_DRQ_PATH  = os.path.join(OUT_DIR, "best_dynamic_range.tflite")
TFLITE_INT8_PATH = os.path.join(OUT_DIR, "best_int8.tflite")
LABELS_TXT       = os.path.join(OUT_DIR, "labels.txt")

np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# ============================================================
# TPU / STRATEGY INIT
# ============================================================
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
    print("TPU:", tpu.master())
except Exception as e:
    strategy = tf.distribute.get_strategy()
    print("TPU not used. Fallback strategy. Reason:", e)

print("Strategy:", type(strategy).__name__)
print("Replicas:", strategy.num_replicas_in_sync)

NUM_REPLICAS = strategy.num_replicas_in_sync
GLOBAL_BATCH = BATCH_PER_REPLICA * NUM_REPLICAS
print("GLOBAL_BATCH:", GLOBAL_BATCH)
# Out:
# TPU not used. Fallback strategy. Reason: Please provide a TPU Name to connect to.
# Strategy: _DefaultDistributionStrategy
# Replicas: 1
# GLOBAL_BATCH: 32

# %% [markdown]
# Data Pipeline Helpers (files → decode/augment → tf.data)

# %%
# ============================================================
# DATA HELPERS
# ============================================================
def list_files(dataset_dir):
    p = pathlib.Path(dataset_dir)
    classes = sorted([d.name for d in p.iterdir() if d.is_dir()])
    paths, labels = [], []
    for i, c in enumerate(classes):
        for x in (p / c).glob("*"):
            if x.suffix.lower() in [".jpg", ".jpeg", ".png"]:
                paths.append(str(x))
                labels.append(i)
    return np.array(paths), np.array(labels), classes

def decode_resize(path, label):
    img_bytes = tf.io.read_file(path)
    is_jpeg = tf.strings.regex_full_match(tf.strings.lower(path), ".*\\.jpe?g")
    img = tf.cond(
        is_jpeg,
        lambda: tf.image.decode_jpeg(img_bytes, channels=3),
        lambda: tf.image.decode_png(img_bytes, channels=3),
    )
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32)
    img = preprocess_input(img)
    return img, label

def augment(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, 0.08)
    img = tf.image.random_contrast(img, 0.9, 1.1)
    k = tf.random.uniform([], 0, 4, dtype=tf.int32)
    img = tf.image.rot90(img, k)
    return img, label

def make_ds(paths, labels, train=False):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    if train:
        ds = ds.shuffle(buffer_size=len(paths), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(decode_resize, num_parallel_calls=AUTOTUNE)
    if train:
        ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(GLOBAL_BATCH, drop_remainder=train).prefetch(AUTOTUNE)
    return ds

def oversample(paths, labels):
    rng = np.random.RandomState(SEED)
    cls, cnt = np.unique(labels, return_counts=True)
    m = cnt.max()
    new_p, new_y = [], []
    for c in cls:
        idx = np.where(labels == c)[0]
        chosen = rng.choice(idx, size=m, replace=True)
        new_p.extend(paths[chosen].tolist())
        new_y.extend([c] * m)
    perm = rng.permutation(len(new_p))
    return np.array(new_p)[perm], np.array(new_y)[perm]

# %% [markdown]
# Model + Focal Loss + Fine-tune

# %%
# ============================================================
# MODEL
# ============================================================
def focal_loss(num_classes, gamma=FOCAL_GAMMA, alpha=FOCAL_ALPHA):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.int32)
        y_one = tf.one_hot(y_true, depth=num_classes)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        ce = -y_one * tf.math.log(y_pred)
        w = alpha * tf.math.pow(1 - y_pred, gamma)
        return tf.reduce_sum(w * ce, axis=1)
    return loss

def build_model(num_classes):
    base = EfficientNetB0(input_shape=IMG_SIZE + (3,), include_top=False, weights="imagenet")
    base.trainable = False
    inp = layers.Input(shape=IMG_SIZE + (3,))
    x = base(inp, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    out = layers.Dense(num_classes, activation="softmax")(x)
    return models.Model(inp, out), base

def compile_model(model, num_classes, lr):
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss=focal_loss(num_classes),
        metrics=["accuracy"],
    )

def fine_tune(base, ratio=FINE_TUNE_RATIO):
    base.trainable = True
    n = len(base.layers)
    fine_at = int(n * ratio)
    for i, layer in enumerate(base.layers):
        layer.trainable = (i >= fine_at)

# %%
# ============================================================
# EVAL
# ============================================================
def eval_metrics(model, ds, class_names):
    y_true, y_pred = [], []
    for x, y in ds:
        p = model.predict(x, verbose=0)
        y_true.extend(y.numpy().tolist())
        y_pred.extend(np.argmax(p, axis=1).tolist())

    rep = classification_report(
        y_true, y_pred, target_names=class_names, output_dict=True, zero_division=0
    )
    acc = rep["accuracy"]
    prec = np.mean([rep[c]["precision"] for c in class_names])
    rec  = np.mean([rep[c]["recall"] for c in class_names])
    f1   = np.mean([rep[c]["f1-score"] for c in class_names])
    return acc, prec, rec, f1

def get_preds(model, ds):
    y_true, y_pred = [], []
    for x, y in ds:
        p = model.predict(x, verbose=0)
        y_true.extend(y.numpy().tolist())
        y_pred.extend(np.argmax(p, axis=1).tolist())
    return np.array(y_true), np.array(y_pred)

# ============================================================
# SAVE 2 GRAPHS
# ============================================================
def save_train_val_plots(h1, h2, loss_path, acc_path):
    def cat(k):
        return list(h1.history.get(k, [])) + list(h2.history.get(k, []))

    tr_loss = cat("loss")
    va_loss = cat("val_loss")
    tr_acc  = cat("accuracy")
    va_acc  = cat("val_accuracy")
    epochs  = np.arange(1, len(tr_loss) + 1)

    plt.figure()
    plt.plot(epochs, tr_loss, label="train_loss")
    plt.plot(epochs, va_loss, label="val_loss")
    plt.xlabel("Epoch"); plt.ylabel("Loss")
    plt.title("Training vs Validation Loss")
    plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(loss_path, dpi=200)
    plt.close()

    plt.figure()
    plt.plot(epochs, tr_acc, label="train_acc")
    plt.plot(epochs, va_acc, label="val_acc")
    plt.xlabel("Epoch"); plt.ylabel("Accuracy")
    plt.title("Training vs Validation Accuracy")
    plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(acc_path, dpi=200)
    plt.close()
# ============================================================
# CONFUSION MATRIX SAVE
# (blue cmap, text always black)
# ============================================================
def save_confusion_matrix_png(y_true, y_pred, class_names, out_path, normalize=False):
    cm = confusion_matrix(y_true, y_pred, labels=np.arange(len(class_names)))

    if normalize:
        cm = cm.astype("float32") / np.maximum(cm.sum(axis=1, keepdims=True), 1e-9)

    plt.figure(figsize=(8, 8))

    vmax = 1.0 if normalize else cm.max()
    plt.imshow(cm, cmap="Blues", vmin=0.0, vmax=vmax)

    plt.title("Confusion Matrix" + (" (Normalized)" if normalize else ""))
    plt.colorbar()

    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45, ha="right")
    plt.yticks(tick_marks, class_names)

    fmt = ".2f" if normalize else "d"

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(
            j, i, format(cm[i, j], fmt),
            ha="center",
            va="center",
            color="black"   # always black text
        )

    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.tight_layout()
    plt.savefig(out_path, dpi=200)
    plt.close()

# %% [markdown]
# RUN: CV on TRAIN only → Final Train/Val → Test Eval + Save Metrics

# %%
# ============================================================
# RUN
# ============================================================
paths, labels, class_names = list_files(DATASET_DIR)
num_classes = len(class_names)
print("Classes:", class_names)
print("Num classes:", num_classes)

# Split: Train vs Test (TEST never touched in CV/training decisions)
train_p, test_p, train_y, test_y = train_test_split(
    paths, labels, test_size=TEST_SIZE, random_state=SEED, stratify=labels
)

# -----------------------
# CV on TRAIN only
# -----------------------
skf = StratifiedKFold(n_splits=KFOLDS, shuffle=True, random_state=SEED)
cv_acc = []

for fold, (tr, va) in enumerate(skf.split(train_p, train_y), start=1):
    tr_p, tr_l = train_p[tr], train_y[tr]
    va_p, va_l = train_p[va], train_y[va]

    tr_p2, tr_l2 = oversample(tr_p, tr_l)
    tr_ds = make_ds(tr_p2, tr_l2, train=True)
    va_ds = make_ds(va_p, va_l, train=False)

    with strategy.scope():
        model, base = build_model(num_classes)
        compile_model(model, num_classes, LR_HEAD)

    cb_cv = [
        callbacks.EarlyStopping(monitor="val_loss", patience=CV_PATIENCE, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(monitor="val_loss", factor=REDUCE_LR_FACTOR, patience=1),
    ]

    model.fit(tr_ds, validation_data=va_ds, epochs=EPOCHS_HEAD, verbose=1, callbacks=cb_cv)

    with strategy.scope():
        fine_tune(base, ratio=FINE_TUNE_RATIO)
        compile_model(model, num_classes, LR_FINE)

    model.fit(tr_ds, validation_data=va_ds, epochs=EPOCHS_FINE, verbose=1, callbacks=cb_cv)

    acc, _, _, _ = eval_metrics(model, va_ds, class_names)
    cv_acc.append(acc)
    print(f"Fold {fold} val accuracy: {acc:.4f}")

cv_mean, cv_std = float(np.mean(cv_acc)), float(np.std(cv_acc))
print(f"\nCV Accuracy (mean ± std): {cv_mean:.4f} ± {cv_std:.4f}")

# -----------------------
# Final Train/Val split from TRAIN only
# -----------------------
final_tr_p, final_va_p, final_tr_y, final_va_y = train_test_split(
    train_p, train_y, test_size=FINAL_VAL_SIZE, random_state=SEED, stratify=train_y
)

final_tr_p2, final_tr_y2 = oversample(final_tr_p, final_tr_y)
final_tr_ds = make_ds(final_tr_p2, final_tr_y2, train=True)
final_va_ds = make_ds(final_va_p, final_va_y, train=False)
test_ds     = make_ds(test_p, test_y, train=False)

# -----------------------
# Final training + checkpoint
# -----------------------
with strategy.scope():
    model, base = build_model(num_classes)
    compile_model(model, num_classes, LR_HEAD)

ckpt = callbacks.ModelCheckpoint(MODEL_PATH, monitor="val_accuracy", save_best_only=True, verbose=1)
cb_final = [
    ckpt,
    callbacks.EarlyStopping(monitor="val_loss", patience=FINAL_PATIENCE, restore_best_weights=True),
    callbacks.ReduceLROnPlateau(monitor="val_loss", factor=REDUCE_LR_FACTOR, patience=1),
]

h1 = model.fit(final_tr_ds, validation_data=final_va_ds, epochs=EPOCHS_HEAD, verbose=1, callbacks=cb_final)

with strategy.scope():
    fine_tune(base, ratio=FINE_TUNE_RATIO)
    compile_model(model, num_classes, LR_FINE)

h2 = model.fit(final_tr_ds, validation_data=final_va_ds, epochs=EPOCHS_FINE, verbose=1, callbacks=cb_final)

# Load best + save clean model (no optimizer)
best = tf.keras.models.load_model(MODEL_PATH, compile=False)
best.save(CLEAN_MODEL_PATH, include_optimizer=False)

# Save plots
save_train_val_plots(h1, h2, LOSS_PNG, ACC_PNG)

# Test evaluation
test_acc, test_prec, test_rec, test_f1 = eval_metrics(best, test_ds, class_names)

# Confusion matrix (normalized)
y_true, y_pred = get_preds(best, test_ds)
save_confusion_matrix_png(y_true, y_pred, class_names, CM_PNG, normalize=True)

# Model size
train_model_size_mb = os.path.getsize(MODEL_PATH) / (1024 * 1024)
clean_model_size_mb = os.path.getsize(CLEAN_MODEL_PATH) / (1024 * 1024)
# Out:
# Classes: ['Biological', 'Metal', 'Paper', 'Plastic']
# Num classes: 4
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 385s 6s/step - accuracy: 0.6043 - loss: 0.5326 - val_accuracy: 0.9140 - val_loss: 0.1120 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.8954 - loss: 0.1327 - val_accuracy: 0.9419 - val_loss: 0.0738 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.9167 - loss: 0.0943 - val_accuracy: 0.9419 - val_loss: 0.0618 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - accuracy: 0.9162 - loss: 0.0867 - val_accuracy: 0.9495 - val_loss: 0.0580 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 165ms/step - accuracy: 0.9353 - loss: 0.0691 - val_accuracy: 0.9430 - val_loss: 0.0624 - learning_rate: 0.0010
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 51s 364ms/step - accuracy: 0.8636 - loss: 0.1800 - val_accuracy: 0.9344 - val_loss: 0.0700 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.8789 - loss: 0.1561 - val_accuracy: 0.9301 - val_loss: 0.0799 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.8913 - loss: 0.1421 - val_accuracy: 0.9226 - val_loss: 0.0884 - learning_rate: 5.0000e-06
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.8915 - loss: 0.1343 - val_accuracy: 0.9215 - val_loss: 0.0951 - learning_rate: 2.5000e-06
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9163 - loss: 0.1181 - val_accuracy: 0.9161 - val_loss: 0.1001 - learning_rate: 1.2500e-06
# Fold 1 val accuracy: 0.9344
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - accuracy: 0.5149 - loss: 0.6769 - val_accuracy: 0.9043 - val_loss: 0.1211 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - accuracy: 0.8794 - loss: 0.1415 - val_accuracy: 0.9226 - val_loss: 0.0896 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 13s 225ms/step - accuracy: 0.9232 - loss: 0.0762 - val_accuracy: 0.9280 - val_loss: 0.0791 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 172ms/step - accuracy: 0.9385 - loss: 0.0707 - val_accuracy: 0.9301 - val_loss: 0.0754 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 163ms/step - accuracy: 0.9374 - loss: 0.0594 - val_accuracy: 0.9366 - val_loss: 0.0730 - learning_rate: 0.0010
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 51s 368ms/step - accuracy: 0.8551 - loss: 0.1786 - val_accuracy: 0.9323 - val_loss: 0.0799 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step - accuracy: 0.8841 - loss: 0.1494 - val_accuracy: 0.9323 - val_loss: 0.0864 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 180ms/step - accuracy: 0.8898 - loss: 0.1350 - val_accuracy: 0.9323 - val_loss: 0.0924 - learning_rate: 5.0000e-06
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 206ms/step - accuracy: 0.9012 - loss: 0.1154 - val_accuracy: 0.9290 - val_loss: 0.0974 - learning_rate: 2.5000e-06
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 9s 162ms/step - accuracy: 0.9190 - loss: 0.1132 - val_accuracy: 0.9280 - val_loss: 0.1010 - learning_rate: 1.2500e-06
# Fold 2 val accuracy: 0.9323
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 59s 670ms/step - accuracy: 0.5188 - loss: 0.5907 - val_accuracy: 0.9075 - val_loss: 0.1076 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 164ms/step - accuracy: 0.8825 - loss: 0.1412 - val_accuracy: 0.9323 - val_loss: 0.0753 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 182ms/step - accuracy: 0.8954 - loss: 0.1177 - val_accuracy: 0.9419 - val_loss: 0.0669 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 181ms/step - accuracy: 0.9158 - loss: 0.0902 - val_accuracy: 0.9484 - val_loss: 0.0590 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.9485 - loss: 0.0758 - val_accuracy: 0.9473 - val_loss: 0.0582 - learning_rate: 0.0010
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 50s 364ms/step - accuracy: 0.8712 - loss: 0.1753 - val_accuracy: 0.9516 - val_loss: 0.0626 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 177ms/step - accuracy: 0.8614 - loss: 0.1701 - val_accuracy: 0.9462 - val_loss: 0.0698 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - accuracy: 0.8961 - loss: 0.1285 - val_accuracy: 0.9430 - val_loss: 0.0770 - learning_rate: 5.0000e-06
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - accuracy: 0.8999 - loss: 0.1292 - val_accuracy: 0.9419 - val_loss: 0.0821 - learning_rate: 2.5000e-06
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - accuracy: 0.8720 - loss: 0.1453 - val_accuracy: 0.9398 - val_loss: 0.0857 - learning_rate: 1.2500e-06
# Fold 3 val accuracy: 0.9516
#
# CV Accuracy (mean ± std): 0.9394 ± 0.0087
# Epoch 1/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.5811 - loss: 0.5171
# Epoch 1: val_accuracy improved from -inf to 0.91885, saving model to /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 48s 386ms/step - accuracy: 0.5833 - loss: 0.5143 - val_accuracy: 0.9189 - val_loss: 0.1087 - learning_rate: 0.0010
# Epoch 2/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8909 - loss: 0.1272
# Epoch 2: val_accuracy improved from 0.91885 to 0.93556, saving model to /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 11s 145ms/step - accuracy: 0.8911 - loss: 0.1270 - val_accuracy: 0.9356 - val_loss: 0.0888 - learning_rate: 0.0010
# Epoch 3/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9252 - loss: 0.0822
# Epoch 3: val_accuracy improved from 0.93556 to 0.94033, saving model to /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 12s 157ms/step - accuracy: 0.9253 - loss: 0.0821 - val_accuracy: 0.9403 - val_loss: 0.0828 - learning_rate: 0.0010
# Epoch 4/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9288 - loss: 0.0729
# Epoch 4: val_accuracy did not improve from 0.94033
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.9288 - loss: 0.0729 - val_accuracy: 0.9356 - val_loss: 0.0788 - learning_rate: 0.0010
# Epoch 5/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9346 - loss: 0.0722
# Epoch 5: val_accuracy did not improve from 0.94033
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 20s 140ms/step - accuracy: 0.9347 - loss: 0.0720 - val_accuracy: 0.9403 - val_loss: 0.0733 - learning_rate: 0.0010
# Epoch 1/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8643 - loss: 0.1597
# Epoch 1: val_accuracy did not improve from 0.94033
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 53s 309ms/step - accuracy: 0.8643 - loss: 0.1596 - val_accuracy: 0.9379 - val_loss: 0.0764 - learning_rate: 1.0000e-05
# Epoch 2/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8778 - loss: 0.1481
# Epoch 2: val_accuracy did not improve from 0.94033
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 11s 150ms/step - accuracy: 0.8780 - loss: 0.1479 - val_accuracy: 0.9308 - val_loss: 0.0815 - learning_rate: 1.0000e-05
# Epoch 3/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8925 - loss: 0.1225
# Epoch 3: val_accuracy did not improve from 0.94033
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.8925 - loss: 0.1225 - val_accuracy: 0.9284 - val_loss: 0.0865 - learning_rate: 5.0000e-06
# Epoch 4/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9094 - loss: 0.1201
# Epoch 4: val_accuracy did not improve from 0.94033
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.9095 - loss: 0.1201 - val_accuracy: 0.9260 - val_loss: 0.0904 - learning_rate: 2.5000e-06
# Epoch 5/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9119 - loss: 0.1083
# Epoch 5: val_accuracy did not improve from 0.94033
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 10s 138ms/step - accuracy: 0.9119 - loss: 0.1083 - val_accuracy: 0.9189 - val_loss: 0.0932 - learning_rate: 1.2500e-06
# Epoch 6/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9128 - loss: 0.1075
# Epoch 6: val_accuracy did not improve from 0.94033
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9129 - loss: 0.1075 - val_accuracy: 0.9212 - val_loss: 0.0949 - learning_rate: 6.2500e-07

# %% [markdown]
# Benchmark + metrics.json save

# %%
# ============================================================
# BENCHMARK
# ============================================================
def benchmark_warm(model, warmup=WARMUP_RUNS, runs=BENCH_RUNS):
    x1 = np.random.rand(1, *IMG_SIZE, 3).astype("float32")
    xb = np.random.rand(GLOBAL_BATCH, *IMG_SIZE, 3).astype("float32")

    for _ in range(warmup):
        _ = model.predict(x1, verbose=0)

    t0 = time.time()
    for _ in range(runs):
        _ = model.predict(x1, verbose=0)
    single_ms = ((time.time() - t0) / runs) * 1000

    for _ in range(warmup):
        _ = model.predict(xb, verbose=0)

    t0 = time.time()
    for _ in range(runs):
        _ = model.predict(xb, verbose=0)
    total = time.time() - t0

    thr = (GLOBAL_BATCH * runs) / total
    eff_ms = 1000.0 / thr
    return single_ms, thr, eff_ms

single_ms, thr, eff_ms = benchmark_warm(best, warmup=WARMUP_RUNS, runs=BENCH_RUNS)
params = int(best.count_params())

out = {
    "model": "EfficientNetB0",
    "classes": class_names,
    "strategy": type(strategy).__name__,
    "replicas": int(NUM_REPLICAS),
    "global_batch": int(GLOBAL_BATCH),
    "cv_accuracy_mean": cv_mean,
    "cv_accuracy_std": cv_std,
    "test_accuracy": float(test_acc),
    "precision_macro": float(test_prec),
    "recall_macro": float(test_rec),
    "f1_macro": float(test_f1),
    "parameters": params,
    "model_size_mb_training_checkpoint": float(train_model_size_mb),
    "model_size_mb_clean_inference": float(clean_model_size_mb),
    "single_image_latency_ms_after_warmup": float(single_ms),
    "throughput_images_per_sec": float(thr),
    "effective_ms_per_image_from_throughput": float(eff_ms),
    "loss_plot_path": LOSS_PNG,
    "accuracy_plot_path": ACC_PNG,
    "confusion_matrix_plot_path": CM_PNG,
}

with open(METRICS_PATH, "w") as f:
    json.dump(out, f, indent=2)

print("\nSaved training checkpoint:", MODEL_PATH)
print("Saved clean inference model:", CLEAN_MODEL_PATH)
print("Saved loss plot:", LOSS_PNG)
print("Saved accuracy plot:", ACC_PNG)
print("Saved confusion matrix:", CM_PNG)
print("Metrics:", METRICS_PATH)
# Out:
# Saved training checkpoint: /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/best.keras
# Saved clean inference model: /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/best_noopt.keras
# Saved loss plot: /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/plots/loss_train_vs_val.png
# Saved accuracy plot: /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/plots/acc_train_vs_val.png
# Saved confusion matrix: /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/plots/confusion_matrix.png
# Metrics: /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/metrics.json

# %% [markdown]
# TFLite Export (FP32 + DRQ + INT8)

# %%
# ============================================================
# TFLite EXPORT
# ============================================================
with open(LABELS_TXT, "w") as f:
    for name in class_names:
        f.write(name + "\n")
print("Saved labels:", LABELS_TXT)

clean = tf.keras.models.load_model(CLEAN_MODEL_PATH, compile=False)

# FP32
converter = tf.lite.TFLiteConverter.from_keras_model(clean)
tflite_fp32 = converter.convert()
with open(TFLITE_FP32_PATH, "wb") as f:
    f.write(tflite_fp32)
print("Saved TFLite FP32:", TFLITE_FP32_PATH)

# Dynamic Range Quant
converter = tf.lite.TFLiteConverter.from_keras_model(clean)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_drq = converter.convert()
with open(TFLITE_DRQ_PATH, "wb") as f:
    f.write(tflite_drq)
print("Saved TFLite Dynamic Range:", TFLITE_DRQ_PATH)

# INT8
def rep_data_gen():
    for x, _ in final_tr_ds.take(REP_BATCHES):
        yield [tf.cast(x, tf.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(clean)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = rep_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

try:
    tflite_int8 = converter.convert()
    with open(TFLITE_INT8_PATH, "wb") as f:
        f.write(tflite_int8)
    print("Saved TFLite INT8:", TFLITE_INT8_PATH)
except Exception as e:
    print("INT8 conversion failed. Reason:", e)
    print("Tip: remove int8 input/output lines for hybrid quantization and try again.")
# Out:
# Saved labels: /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/labels.txt
# Saved artifact at '/tmp/tmpt8de9x9k'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   136353437241360: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136353437243664: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136357448527376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448527184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448522576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448520464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448525264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448522192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448527760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448523728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448524112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448521616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448527952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448525840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448525648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448520272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440497744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440498896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440498128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440499280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440499856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440499088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440497936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440499664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440500240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440500816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440500048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440498320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440500624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440499472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440500432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440502544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440502736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440502160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440503120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440503696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440502352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440503504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440504080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440504656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440503888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440502928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440504464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440504848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440503312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440504272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136360477307344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439416784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439416400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439416976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439432336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439432528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439432144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438269904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438269520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437237712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437237904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437237328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437241552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437241744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437243280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437243472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242896: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite FP32: /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/best_fp32.tflite
# Saved artifact at '/tmp/tmp9gdx115x'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   136353437241360: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136353437243664: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136357448527376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448527184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448522576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448520464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448525264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448522192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448527760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448523728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448524112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448521616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448527952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448525840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448525648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448520272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440497744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440498896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440498128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440499280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440499856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440499088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440497936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440499664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440500240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440500816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440500048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440498320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440500624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440499472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440500432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440502544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440502736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440502160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440503120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440503696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440502352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440503504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440504080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440504656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440503888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440502928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440504464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440504848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440503312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440504272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440501584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136360477307344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439416784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439416400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439416976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439432336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439432528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439432144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438269904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438269520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437237712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437237904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437237328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437241552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437241744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437243280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437243472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242896: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite Dynamic Range: /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/best_dynamic_range.tflite
# Saved artifact at '/tmp/tmp7b5ilz2b'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   136353437241360: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136353437243664: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136357448527376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448527184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448522576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448520464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448525264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448522192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448527760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448523728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448524112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448521616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448527952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448526608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448525840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448525648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448529104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448520272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448531792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448528528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136357448530064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440497744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440498896: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
#   136353440508688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440506960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440507920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136360477307344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440508880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440505232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440511760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440510416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440509648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440512720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353440513296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439416784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439416400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439417168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439416976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439418704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439419280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439420624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439421584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439423120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439424464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439425424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439422736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439427152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439428112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439429072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439432336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439431952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439432528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439432144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439430224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353439426384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438269904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438271632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438270288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438272592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438273552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438269520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438275280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438276240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438277200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438278736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438279696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438280080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438281040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438282192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438274512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438284880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438285648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353438283920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437237712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437237904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437237328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437239248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437241552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437240208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437238672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437241744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437243280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437243472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136353437242896: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Saved TFLite INT8: /content/drive/MyDrive/ImageClassification/OUT_EfficientNetB0/best_int8.tflite
