# %%
# Mount Drive (Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os, time, json, pathlib, itertools
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet import preprocess_input
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

# ============================================================
# CONFIG (EDIT ONLY HERE)
# ============================================================
DATASET_DIR = "/content/drive/MyDrive/ImageClassification/TrashData"
OUT_DIR     = "/content/drive/MyDrive/ImageClassification/OUT_ResNet50"
IMG_SIZE    = (224, 224)

LR_HEAD = 1e-3
LR_FINE = 1e-5

BATCH_PER_REPLICA = 32 #32
SEED             = 42
KFOLDS           = 3
EPOCHS_HEAD      = 5
EPOCHS_FINE      = 10
CV_PATIENCE      = 4
FINAL_PATIENCE   = 5

WARMUP_RUNS      = 7 #7
BENCH_RUNS       = 10
REP_BATCHES      = 15  #10

TEST_SIZE        = 0.30
FINAL_VAL_SIZE   = 0.15
FINE_TUNE_RATIO  = 0.8

FOCAL_GAMMA      = 2.0
FOCAL_ALPHA      = 1.0   # standard 1
REDUCE_LR_FACTOR = 0.5

AUTOTUNE = tf.data.AUTOTUNE

# ============================================================
# OUTPUT PATHS
# ============================================================
os.makedirs(OUT_DIR, exist_ok=True)
PLOTS_DIR = os.path.join(OUT_DIR, "plots")
os.makedirs(PLOTS_DIR, exist_ok=True)

MODEL_PATH       = os.path.join(OUT_DIR, "best.keras")
CLEAN_MODEL_PATH = os.path.join(OUT_DIR, "best_noopt.keras")
METRICS_PATH     = os.path.join(OUT_DIR, "metrics.json")

LOSS_PNG = os.path.join(PLOTS_DIR, "loss_train_vs_val.png")
ACC_PNG  = os.path.join(PLOTS_DIR, "acc_train_vs_val.png")
CM_PNG   = os.path.join(PLOTS_DIR, "confusion_matrix.png")

TFLITE_FP32_PATH = os.path.join(OUT_DIR, "best_fp32.tflite")
TFLITE_DRQ_PATH  = os.path.join(OUT_DIR, "best_dynamic_range.tflite")
TFLITE_INT8_PATH = os.path.join(OUT_DIR, "best_int8.tflite")
LABELS_TXT       = os.path.join(OUT_DIR, "labels.txt")

np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# ============================================================
# TPU / STRATEGY INIT
# ============================================================
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
    print("TPU:", tpu.master())
except Exception as e:
    strategy = tf.distribute.get_strategy()
    print("TPU not used. Fallback strategy. Reason:", e)

print("Strategy:", type(strategy).__name__)
print("Replicas:", strategy.num_replicas_in_sync)

NUM_REPLICAS = strategy.num_replicas_in_sync
GLOBAL_BATCH = BATCH_PER_REPLICA * NUM_REPLICAS
print("GLOBAL_BATCH:", GLOBAL_BATCH)
# Out:
# TPU not used. Fallback strategy. Reason: Please provide a TPU Name to connect to.
# Strategy: _DefaultDistributionStrategy
# Replicas: 1
# GLOBAL_BATCH: 32

# %%
# ============================================================
# DATA HELPERS
# ============================================================
def list_files(dataset_dir):
    p = pathlib.Path(dataset_dir)
    classes = sorted([d.name for d in p.iterdir() if d.is_dir()])
    paths, labels = [], []
    for i, c in enumerate(classes):
        for x in (p / c).glob("*"):
            if x.suffix.lower() in [".jpg", ".jpeg", ".png"]:
                paths.append(str(x))
                labels.append(i)
    return np.array(paths), np.array(labels), classes

def decode_resize(path, label):
    img_bytes = tf.io.read_file(path)
    is_jpeg = tf.strings.regex_full_match(tf.strings.lower(path), ".*\\.jpe?g")
    img = tf.cond(
        is_jpeg,
        lambda: tf.image.decode_jpeg(img_bytes, channels=3),
        lambda: tf.image.decode_png(img_bytes, channels=3),
    )
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32)
    img = preprocess_input(img)  # ResNet preprocess
    return img, label

def augment(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, 0.08)
    img = tf.image.random_contrast(img, 0.9, 1.1)
    k = tf.random.uniform([], 0, 4, dtype=tf.int32)
    img = tf.image.rot90(img, k)
    return img, label

def make_ds(paths, labels, train=False):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    if train:
        ds = ds.shuffle(buffer_size=len(paths), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(decode_resize, num_parallel_calls=AUTOTUNE)
    if train:
        ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(GLOBAL_BATCH, drop_remainder=train).prefetch(AUTOTUNE)
    return ds

def oversample(paths, labels):
    rng = np.random.RandomState(SEED)
    cls, cnt = np.unique(labels, return_counts=True)
    m = cnt.max()
    new_p, new_y = [], []
    for c in cls:
        idx = np.where(labels == c)[0]
        chosen = rng.choice(idx, size=m, replace=True)
        new_p.extend(paths[chosen].tolist())
        new_y.extend([c] * m)
    perm = rng.permutation(len(new_p))
    return np.array(new_p)[perm], np.array(new_y)[perm]

# %%
# ============================================================
# MODEL
# ============================================================
def focal_loss(num_classes, gamma=FOCAL_GAMMA, alpha=FOCAL_ALPHA):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.int32)
        y_one = tf.one_hot(y_true, depth=num_classes)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        ce = -y_one * tf.math.log(y_pred)
        w = alpha * tf.math.pow(1 - y_pred, gamma)
        return tf.reduce_sum(w * ce, axis=1)
    return loss

def build_model(num_classes):
    base = ResNet50(input_shape=IMG_SIZE + (3,), include_top=False, weights="imagenet")
    base.trainable = False

    inp = layers.Input(shape=IMG_SIZE + (3,))
    x = base(inp, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    out = layers.Dense(num_classes, activation="softmax")(x)
    return models.Model(inp, out), base

def compile_model(model, num_classes, lr):
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss=focal_loss(num_classes),
        metrics=["accuracy"],
    )

def fine_tune(base, ratio=FINE_TUNE_RATIO):
    base.trainable = True
    n = len(base.layers)
    fine_at = int(n * ratio)
    for i, layer in enumerate(base.layers):
        layer.trainable = (i >= fine_at)

# %%
# ============================================================
# EVAL
# ============================================================
def eval_metrics(model, ds, class_names):
    y_true, y_pred = [], []
    for x, y in ds:
        p = model.predict(x, verbose=0)
        y_true.extend(y.numpy().tolist())
        y_pred.extend(np.argmax(p, axis=1).tolist())

    rep = classification_report(
        y_true, y_pred, target_names=class_names, output_dict=True, zero_division=0
    )
    acc = rep["accuracy"]
    prec = np.mean([rep[c]["precision"] for c in class_names])
    rec  = np.mean([rep[c]["recall"] for c in class_names])
    f1   = np.mean([rep[c]["f1-score"] for c in class_names])
    return acc, prec, rec, f1

def get_preds(model, ds):
    y_true, y_pred = [], []
    for x, y in ds:
        p = model.predict(x, verbose=0)
        y_true.extend(y.numpy().tolist())
        y_pred.extend(np.argmax(p, axis=1).tolist())
    return np.array(y_true), np.array(y_pred)

# ============================================================
# SAVE 2 GRAPHS
# ============================================================
def save_train_val_plots(h1, h2, loss_path, acc_path):
    def cat(k):
        return list(h1.history.get(k, [])) + list(h2.history.get(k, []))

    tr_loss = cat("loss")
    va_loss = cat("val_loss")
    tr_acc  = cat("accuracy")
    va_acc  = cat("val_accuracy")
    epochs  = np.arange(1, len(tr_loss) + 1)

    plt.figure()
    plt.plot(epochs, tr_loss, label="train_loss")
    plt.plot(epochs, va_loss, label="val_loss")
    plt.xlabel("Epoch"); plt.ylabel("Loss")
    plt.title("Training vs Validation Loss")
    plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(loss_path, dpi=200)
    plt.close()

    plt.figure()
    plt.plot(epochs, tr_acc, label="train_acc")
    plt.plot(epochs, va_acc, label="val_acc")
    plt.xlabel("Epoch"); plt.ylabel("Accuracy")
    plt.title("Training vs Validation Accuracy")
    plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(acc_path, dpi=200)
    plt.close()

# ============================================================
# CONFUSION MATRIX SAVE
# (blue cmap, text always black)
# ============================================================
def save_confusion_matrix_png(y_true, y_pred, class_names, out_path, normalize=False):
    cm = confusion_matrix(y_true, y_pred, labels=np.arange(len(class_names)))

    if normalize:
        cm = cm.astype("float32") / np.maximum(cm.sum(axis=1, keepdims=True), 1e-9)

    plt.figure(figsize=(8, 8))

    vmax = 1.0 if normalize else cm.max()
    plt.imshow(cm, cmap="Blues", vmin=0.0, vmax=vmax)

    plt.title("Confusion Matrix" + (" (Normalized)" if normalize else ""))
    plt.colorbar()

    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45, ha="right")
    plt.yticks(tick_marks, class_names)

    fmt = ".2f" if normalize else "d"
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 ha="center", va="center", color="black")

    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.tight_layout()
    plt.savefig(out_path, dpi=200)
    plt.close()

# %%
# ============================================================
# RUN
# ============================================================
paths, labels, class_names = list_files(DATASET_DIR)
num_classes = len(class_names)
print("Classes:", class_names)
print("Num classes:", num_classes)

# Split: Train vs Test (TEST never touched in CV/training decisions)
train_p, test_p, train_y, test_y = train_test_split(
    paths, labels, test_size=TEST_SIZE, random_state=SEED, stratify=labels
)

# -----------------------
# CV on TRAIN only
# -----------------------
skf = StratifiedKFold(n_splits=KFOLDS, shuffle=True, random_state=SEED)
cv_acc = []

for fold, (tr, va) in enumerate(skf.split(train_p, train_y), start=1):
    tr_p, tr_l = train_p[tr], train_y[tr]
    va_p, va_l = train_p[va], train_y[va]

    tr_p2, tr_l2 = oversample(tr_p, tr_l)
    tr_ds = make_ds(tr_p2, tr_l2, train=True)
    va_ds = make_ds(va_p, va_l, train=False)

    with strategy.scope():
        model, base = build_model(num_classes)
        compile_model(model, num_classes, LR_HEAD)

    cb_cv = [
        callbacks.EarlyStopping(monitor="val_loss", patience=CV_PATIENCE, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(monitor="val_loss", factor=REDUCE_LR_FACTOR, patience=1),
    ]

    model.fit(tr_ds, validation_data=va_ds, epochs=EPOCHS_HEAD, verbose=1, callbacks=cb_cv)

    with strategy.scope():
        fine_tune(base, ratio=FINE_TUNE_RATIO)
        compile_model(model, num_classes, LR_FINE)

    model.fit(tr_ds, validation_data=va_ds, epochs=EPOCHS_FINE, verbose=1, callbacks=cb_cv)

    acc, _, _, _ = eval_metrics(model, va_ds, class_names)
    cv_acc.append(acc)
    print(f"Fold {fold} val accuracy: {acc:.4f}")

cv_mean, cv_std = float(np.mean(cv_acc)), float(np.std(cv_acc))
print(f"\nCV Accuracy (mean ± std): {cv_mean:.4f} ± {cv_std:.4f}")

# -----------------------
# Final Train/Val split from TRAIN only
# -----------------------
final_tr_p, final_va_p, final_tr_y, final_va_y = train_test_split(
    train_p, train_y, test_size=FINAL_VAL_SIZE, random_state=SEED, stratify=train_y
)

final_tr_p2, final_tr_y2 = oversample(final_tr_p, final_tr_y)
final_tr_ds = make_ds(final_tr_p2, final_tr_y2, train=True)
final_va_ds = make_ds(final_va_p, final_va_y, train=False)
test_ds     = make_ds(test_p, test_y, train=False)

# -----------------------
# Final training + checkpoint
# -----------------------
with strategy.scope():
    model, base = build_model(num_classes)
    compile_model(model, num_classes, LR_HEAD)

ckpt = callbacks.ModelCheckpoint(MODEL_PATH, monitor="val_accuracy", save_best_only=True, verbose=1)
cb_final = [
    ckpt,
    callbacks.EarlyStopping(monitor="val_loss", patience=FINAL_PATIENCE, restore_best_weights=True),
    callbacks.ReduceLROnPlateau(monitor="val_loss", factor=REDUCE_LR_FACTOR, patience=1),
]

h1 = model.fit(final_tr_ds, validation_data=final_va_ds, epochs=EPOCHS_HEAD, verbose=1, callbacks=cb_final)

with strategy.scope():
    fine_tune(base, ratio=FINE_TUNE_RATIO)
    compile_model(model, num_classes, LR_FINE)

h2 = model.fit(final_tr_ds, validation_data=final_va_ds, epochs=EPOCHS_FINE, verbose=1, callbacks=cb_final)

# Load best + save clean model (no optimizer)
best = tf.keras.models.load_model(MODEL_PATH, compile=False)
best.save(CLEAN_MODEL_PATH, include_optimizer=False)

# Save plots
save_train_val_plots(h1, h2, LOSS_PNG, ACC_PNG)

# Test evaluation
test_acc, test_prec, test_rec, test_f1 = eval_metrics(best, test_ds, class_names)

# Confusion matrix (normalized)
y_true, y_pred = get_preds(best, test_ds)
save_confusion_matrix_png(y_true, y_pred, class_names, CM_PNG, normalize=True)

# Model size
train_model_size_mb = os.path.getsize(MODEL_PATH) / (1024 * 1024)
clean_model_size_mb = os.path.getsize(CLEAN_MODEL_PATH) / (1024 * 1024)
# Out:
# Classes: ['Biological', 'Metal', 'Paper', 'Plastic']
# Num classes: 4
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 627s 11s/step - accuracy: 0.5161 - loss: 1.0086 - val_accuracy: 0.9140 - val_loss: 0.1243 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 555s 10s/step - accuracy: 0.8690 - loss: 0.1836 - val_accuracy: 0.9409 - val_loss: 0.0899 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 551s 10s/step - accuracy: 0.8979 - loss: 0.1229 - val_accuracy: 0.9419 - val_loss: 0.1036 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 531s 9s/step - accuracy: 0.9206 - loss: 0.1239 - val_accuracy: 0.9505 - val_loss: 0.0865 - learning_rate: 5.0000e-04
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 531s 9s/step - accuracy: 0.9130 - loss: 0.1336 - val_accuracy: 0.9505 - val_loss: 0.0988 - learning_rate: 5.0000e-04
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 773s 13s/step - accuracy: 0.9077 - loss: 0.1284 - val_accuracy: 0.9462 - val_loss: 0.0898 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 810s 14s/step - accuracy: 0.9224 - loss: 0.0888 - val_accuracy: 0.9505 - val_loss: 0.0954 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 796s 14s/step - accuracy: 0.9375 - loss: 0.0745 - val_accuracy: 0.9527 - val_loss: 0.0973 - learning_rate: 5.0000e-06
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 791s 14s/step - accuracy: 0.9223 - loss: 0.0746 - val_accuracy: 0.9484 - val_loss: 0.0993 - learning_rate: 2.5000e-06
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 764s 13s/step - accuracy: 0.9520 - loss: 0.0474 - val_accuracy: 0.9462 - val_loss: 0.1010 - learning_rate: 1.2500e-06
# Fold 1 val accuracy: 0.9462
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 553s 9s/step - accuracy: 0.5362 - loss: 0.9052 - val_accuracy: 0.8828 - val_loss: 0.1608 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 559s 10s/step - accuracy: 0.8668 - loss: 0.1901 - val_accuracy: 0.9129 - val_loss: 0.1279 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 554s 10s/step - accuracy: 0.9216 - loss: 0.1139 - val_accuracy: 0.9237 - val_loss: 0.1169 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 556s 10s/step - accuracy: 0.9291 - loss: 0.0849 - val_accuracy: 0.9226 - val_loss: 0.1170 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 537s 9s/step - accuracy: 0.9162 - loss: 0.0934 - val_accuracy: 0.9323 - val_loss: 0.1010 - learning_rate: 5.0000e-04
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 796s 13s/step - accuracy: 0.9210 - loss: 0.0953 - val_accuracy: 0.9333 - val_loss: 0.0962 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 769s 13s/step - accuracy: 0.9465 - loss: 0.0665 - val_accuracy: 0.9344 - val_loss: 0.0935 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 767s 13s/step - accuracy: 0.9392 - loss: 0.0549 - val_accuracy: 0.9409 - val_loss: 0.0912 - learning_rate: 1.0000e-05
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 773s 13s/step - accuracy: 0.9583 - loss: 0.0459 - val_accuracy: 0.9376 - val_loss: 0.0911 - learning_rate: 1.0000e-05
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 765s 13s/step - accuracy: 0.9584 - loss: 0.0411 - val_accuracy: 0.9366 - val_loss: 0.0917 - learning_rate: 5.0000e-06
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 830s 14s/step - accuracy: 0.9631 - loss: 0.0381 - val_accuracy: 0.9398 - val_loss: 0.0910 - learning_rate: 2.5000e-06
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 768s 13s/step - accuracy: 0.9639 - loss: 0.0320 - val_accuracy: 0.9398 - val_loss: 0.0900 - learning_rate: 2.5000e-06
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 791s 14s/step - accuracy: 0.9742 - loss: 0.0246 - val_accuracy: 0.9387 - val_loss: 0.0896 - learning_rate: 2.5000e-06
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 790s 14s/step - accuracy: 0.9730 - loss: 0.0267 - val_accuracy: 0.9409 - val_loss: 0.0899 - learning_rate: 2.5000e-06
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 786s 14s/step - accuracy: 0.9728 - loss: 0.0316 - val_accuracy: 0.9387 - val_loss: 0.0898 - learning_rate: 1.2500e-06
# Fold 2 val accuracy: 0.9387
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 583s 10s/step - accuracy: 0.5442 - loss: 0.9812 - val_accuracy: 0.9269 - val_loss: 0.0962 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 548s 9s/step - accuracy: 0.8776 - loss: 0.1843 - val_accuracy: 0.9290 - val_loss: 0.0897 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 559s 10s/step - accuracy: 0.9062 - loss: 0.1387 - val_accuracy: 0.9452 - val_loss: 0.0806 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 558s 10s/step - accuracy: 0.9080 - loss: 0.1157 - val_accuracy: 0.9473 - val_loss: 0.0786 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 560s 10s/step - accuracy: 0.9141 - loss: 0.1073 - val_accuracy: 0.9441 - val_loss: 0.0739 - learning_rate: 0.0010
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 758s 13s/step - accuracy: 0.9193 - loss: 0.1090 - val_accuracy: 0.9462 - val_loss: 0.0867 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 740s 13s/step - accuracy: 0.9273 - loss: 0.0888 - val_accuracy: 0.9430 - val_loss: 0.0861 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 769s 13s/step - accuracy: 0.9470 - loss: 0.0621 - val_accuracy: 0.9462 - val_loss: 0.0811 - learning_rate: 1.0000e-05
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 775s 13s/step - accuracy: 0.9473 - loss: 0.0534 - val_accuracy: 0.9495 - val_loss: 0.0795 - learning_rate: 1.0000e-05
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 751s 13s/step - accuracy: 0.9610 - loss: 0.0465 - val_accuracy: 0.9527 - val_loss: 0.0795 - learning_rate: 1.0000e-05
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 747s 13s/step - accuracy: 0.9516 - loss: 0.0513 - val_accuracy: 0.9505 - val_loss: 0.0795 - learning_rate: 5.0000e-06
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 746s 13s/step - accuracy: 0.9679 - loss: 0.0284 - val_accuracy: 0.9505 - val_loss: 0.0795 - learning_rate: 2.5000e-06
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 747s 13s/step - accuracy: 0.9707 - loss: 0.0258 - val_accuracy: 0.9495 - val_loss: 0.0794 - learning_rate: 1.2500e-06
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 772s 13s/step - accuracy: 0.9703 - loss: 0.0258 - val_accuracy: 0.9495 - val_loss: 0.0788 - learning_rate: 1.2500e-06
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 752s 13s/step - accuracy: 0.9656 - loss: 0.0406 - val_accuracy: 0.9495 - val_loss: 0.0780 - learning_rate: 1.2500e-06
# Fold 3 val accuracy: 0.9495
#
# CV Accuracy (mean ± std): 0.9448 ± 0.0045
# Epoch 1/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6007 - loss: 0.8009
# Epoch 1: val_accuracy improved from -inf to 0.92601, saving model to /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 539s 7s/step - accuracy: 0.6026 - loss: 0.7961 - val_accuracy: 0.9260 - val_loss: 0.1091 - learning_rate: 0.0010
# Epoch 2/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.8847 - loss: 0.1723
# Epoch 2: val_accuracy improved from 0.92601 to 0.93795, saving model to /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 529s 7s/step - accuracy: 0.8849 - loss: 0.1719 - val_accuracy: 0.9379 - val_loss: 0.0878 - learning_rate: 0.0010
# Epoch 3/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9087 - loss: 0.1198
# Epoch 3: val_accuracy did not improve from 0.93795
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 529s 7s/step - accuracy: 0.9087 - loss: 0.1197 - val_accuracy: 0.9379 - val_loss: 0.0944 - learning_rate: 0.0010
# Epoch 4/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9305 - loss: 0.0880
# Epoch 4: val_accuracy improved from 0.93795 to 0.94511, saving model to /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 526s 7s/step - accuracy: 0.9306 - loss: 0.0880 - val_accuracy: 0.9451 - val_loss: 0.0902 - learning_rate: 5.0000e-04
# Epoch 5/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.9366 - loss: 0.0878
# Epoch 5: val_accuracy did not improve from 0.94511
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 527s 7s/step - accuracy: 0.9367 - loss: 0.0876 - val_accuracy: 0.9403 - val_loss: 0.0843 - learning_rate: 2.5000e-04
# Epoch 1/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9077 - loss: 0.1299
# Epoch 1: val_accuracy improved from 0.94511 to 0.94988, saving model to /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 823s 11s/step - accuracy: 0.9077 - loss: 0.1297 - val_accuracy: 0.9499 - val_loss: 0.0882 - learning_rate: 1.0000e-05
# Epoch 2/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9338 - loss: 0.0810
# Epoch 2: val_accuracy did not improve from 0.94988
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 825s 11s/step - accuracy: 0.9339 - loss: 0.0809 - val_accuracy: 0.9451 - val_loss: 0.0853 - learning_rate: 1.0000e-05
# Epoch 3/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9490 - loss: 0.0541
# Epoch 3: val_accuracy did not improve from 0.94988
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 808s 11s/step - accuracy: 0.9490 - loss: 0.0542 - val_accuracy: 0.9451 - val_loss: 0.0792 - learning_rate: 1.0000e-05
# Epoch 4/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9480 - loss: 0.0548
# Epoch 4: val_accuracy did not improve from 0.94988
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 807s 11s/step - accuracy: 0.9481 - loss: 0.0547 - val_accuracy: 0.9475 - val_loss: 0.0781 - learning_rate: 1.0000e-05
# Epoch 5/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9586 - loss: 0.0554
# Epoch 5: val_accuracy improved from 0.94988 to 0.95465, saving model to /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 823s 11s/step - accuracy: 0.9587 - loss: 0.0553 - val_accuracy: 0.9547 - val_loss: 0.0787 - learning_rate: 1.0000e-05
# Epoch 6/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9628 - loss: 0.0424
# Epoch 6: val_accuracy improved from 0.95465 to 0.95704, saving model to /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 821s 11s/step - accuracy: 0.9629 - loss: 0.0423 - val_accuracy: 0.9570 - val_loss: 0.0767 - learning_rate: 5.0000e-06
# Epoch 7/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9655 - loss: 0.0299
# Epoch 7: val_accuracy did not improve from 0.95704
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 811s 11s/step - accuracy: 0.9656 - loss: 0.0299 - val_accuracy: 0.9547 - val_loss: 0.0748 - learning_rate: 5.0000e-06
# Epoch 8/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9665 - loss: 0.0412
# Epoch 8: val_accuracy did not improve from 0.95704
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 799s 11s/step - accuracy: 0.9665 - loss: 0.0411 - val_accuracy: 0.9570 - val_loss: 0.0752 - learning_rate: 5.0000e-06
# Epoch 9/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9729 - loss: 0.0223
# Epoch 9: val_accuracy did not improve from 0.95704
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 797s 11s/step - accuracy: 0.9729 - loss: 0.0223 - val_accuracy: 0.9570 - val_loss: 0.0744 - learning_rate: 2.5000e-06
# Epoch 10/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.9739 - loss: 0.0257
# Epoch 10: val_accuracy did not improve from 0.95704
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 805s 11s/step - accuracy: 0.9739 - loss: 0.0258 - val_accuracy: 0.9570 - val_loss: 0.0737 - learning_rate: 2.5000e-06

# %%
# ============================================================
# BENCHMARK
# ============================================================
def benchmark_warm(model, warmup=WARMUP_RUNS, runs=BENCH_RUNS):
    x1 = np.random.rand(1, *IMG_SIZE, 3).astype("float32")
    xb = np.random.rand(GLOBAL_BATCH, *IMG_SIZE, 3).astype("float32")

    for _ in range(warmup):
        _ = model.predict(x1, verbose=0)

    t0 = time.time()
    for _ in range(runs):
        _ = model.predict(x1, verbose=0)
    single_ms = ((time.time() - t0) / runs) * 1000

    for _ in range(warmup):
        _ = model.predict(xb, verbose=0)

    t0 = time.time()
    for _ in range(runs):
        _ = model.predict(xb, verbose=0)
    total = time.time() - t0

    thr = (GLOBAL_BATCH * runs) / total
    eff_ms = 1000.0 / thr
    return single_ms, thr, eff_ms

single_ms, thr, eff_ms = benchmark_warm(best, warmup=WARMUP_RUNS, runs=BENCH_RUNS)
params = int(best.count_params())

out = {
    "model": "ResNet50",
    "classes": class_names,
    "strategy": type(strategy).__name__,
    "replicas": int(NUM_REPLICAS),
    "global_batch": int(GLOBAL_BATCH),
    "cv_accuracy_mean": cv_mean,
    "cv_accuracy_std": cv_std,
    "test_accuracy": float(test_acc),
    "precision_macro": float(test_prec),
    "recall_macro": float(test_rec),
    "f1_macro": float(test_f1),
    "parameters": params,
    "model_size_mb_training_checkpoint": float(train_model_size_mb),
    "model_size_mb_clean_inference": float(clean_model_size_mb),
    "single_image_latency_ms_after_warmup": float(single_ms),
    "throughput_images_per_sec": float(thr),
    "effective_ms_per_image_from_throughput": float(eff_ms),
    "loss_plot_path": LOSS_PNG,
    "accuracy_plot_path": ACC_PNG,
    "confusion_matrix_plot_path": CM_PNG,
}

with open(METRICS_PATH, "w") as f:
    json.dump(out, f, indent=2)

print("\nSaved training checkpoint:", MODEL_PATH)
print("Saved clean inference model:", CLEAN_MODEL_PATH)
print("Saved loss plot:", LOSS_PNG)
print("Saved accuracy plot:", ACC_PNG)
print("Saved confusion matrix:", CM_PNG)
print("Metrics:", METRICS_PATH)
# Out:
# Saved training checkpoint: /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best.keras
# Saved clean inference model: /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best_noopt.keras
# Saved loss plot: /content/drive/MyDrive/ImageClassification/OUT_ResNet50/plots/loss_train_vs_val.png
# Saved accuracy plot: /content/drive/MyDrive/ImageClassification/OUT_ResNet50/plots/acc_train_vs_val.png
# Saved confusion matrix: /content/drive/MyDrive/ImageClassification/OUT_ResNet50/plots/confusion_matrix.png
# Metrics: /content/drive/MyDrive/ImageClassification/OUT_ResNet50/metrics.json

# %%
# ============================================================
# TFLite EXPORT
# ============================================================
with open(LABELS_TXT, "w") as f:
    for name in class_names:
        f.write(name + "\n")
print("Saved labels:", LABELS_TXT)

clean = tf.keras.models.load_model(CLEAN_MODEL_PATH, compile=False)

# FP32
converter = tf.lite.TFLiteConverter.from_keras_model(clean)
tflite_fp32 = converter.convert()
with open(TFLITE_FP32_PATH, "wb") as f:
    f.write(tflite_fp32)
print("Saved TFLite FP32:", TFLITE_FP32_PATH)

# Dynamic Range Quant
converter = tf.lite.TFLiteConverter.from_keras_model(clean)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_drq = converter.convert()
with open(TFLITE_DRQ_PATH, "wb") as f:
    f.write(tflite_drq)
print("Saved TFLite Dynamic Range:", TFLITE_DRQ_PATH)

# INT8
def rep_data_gen():
    for x, _ in final_tr_ds.take(REP_BATCHES):
        yield [tf.cast(x, tf.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(clean)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = rep_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

try:
    tflite_int8 = converter.convert()
    with open(TFLITE_INT8_PATH, "wb") as f:
        f.write(tflite_int8)
    print("Saved TFLite INT8:", TFLITE_INT8_PATH)
except Exception as e:
    print("INT8 conversion failed. Reason:", e)
    print("Tip: remove int8 input/output lines for hybrid quantization and try again.")
# Out:
# Saved labels: /content/drive/MyDrive/ImageClassification/OUT_ResNet50/labels.txt
# Saved artifact at '/tmp/tmp3ylu776v'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   138294342506576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342502352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342501776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342502928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342511184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342512336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342512144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342511952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342511376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342513488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342513296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342511568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342513104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342512528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342514640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342514448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342512720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342514256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342513680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342511760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342513872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342516560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342514064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342512912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342514832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342516368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359377296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342516176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359375952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359377104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359377488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138295039129360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359377680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359377872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359392080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357917968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357917776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356672144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356671952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356671376: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite FP32: /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best_fp32.tflite
# Saved artifact at '/tmp/tmpgio7156z'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   138294342506576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342502352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342501776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342502928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342511184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342512336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342512144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342511952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342511376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342513488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342513296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342511568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342513104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342512528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342514640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342514448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342512720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342514256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342513680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342511760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342513872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342516560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342514064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342512912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342514832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342516368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359377296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342515216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342516176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359375952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359377104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359377488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138295039129360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359377680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359377872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359392080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357917968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357917776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356672144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356671952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356671376: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite Dynamic Range: /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best_dynamic_range.tflite
# Saved artifact at '/tmp/tmphkiyojn8'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   138294342506576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342502352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342504464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342505424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342507920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342501776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342506768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342503504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342508112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342510032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294342509456: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
#   138294359381520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359380944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359378832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359379408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359376528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359381328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359382480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359383632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359384784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359386896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359385936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359387088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359392080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359390544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359388240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359389392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294359391888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357920080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357918352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357917968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357919504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357917776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357921808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357923920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357922960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357924112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357925264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357926416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357927568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357928720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357930832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357929872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357931024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357932176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294357933136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356656208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356657744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356659856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356658896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356661200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356664080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356662160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356663504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356660048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356665808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356667920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356666960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356669072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356668112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356672144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356671952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356670416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138294356671376: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Saved TFLite INT8: /content/drive/MyDrive/ImageClassification/OUT_ResNet50/best_int8.tflite
