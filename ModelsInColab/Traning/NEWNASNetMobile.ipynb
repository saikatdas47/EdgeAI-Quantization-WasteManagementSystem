# %%
# Mount Drive (Colab)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ============================================================
# SECTION 1: IMPORTS + CONFIG
# ============================================================
import os, time, json, pathlib, itertools
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import layers, models, callbacks, optimizers
from tensorflow.keras.applications import NASNetMobile
from tensorflow.keras.applications.nasnet import preprocess_input

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix

# ============================================================
# CONFIG (EDIT ONLY HERE)
# ============================================================
DATASET_DIR = "/content/drive/MyDrive/ImageClassification/TrashData"
OUT_DIR     = "/content/drive/MyDrive/ImageClassification/OUT_NASNetMobile"
IMG_SIZE    = (224, 224)

LR_HEAD = 1e-3
LR_FINE = 1e-5

BATCH_PER_REPLICA = 32
SEED             = 42
KFOLDS           = 3
EPOCHS_HEAD      = 5
EPOCHS_FINE      = 10
CV_PATIENCE      = 4
FINAL_PATIENCE   = 5

WARMUP_RUNS      = 7
BENCH_RUNS       = 10
REP_BATCHES      = 15

TEST_SIZE        = 0.30
FINAL_VAL_SIZE   = 0.15
FINE_TUNE_RATIO  = 0.8

FOCAL_GAMMA      = 2.0
FOCAL_ALPHA      = 1.0
REDUCE_LR_FACTOR = 0.5

AUTOTUNE = tf.data.AUTOTUNE

# ============================================================
# OUTPUT PATHS
# ============================================================
os.makedirs(OUT_DIR, exist_ok=True)
PLOTS_DIR = os.path.join(OUT_DIR, "plots")
os.makedirs(PLOTS_DIR, exist_ok=True)

MODEL_PATH       = os.path.join(OUT_DIR, "best.keras")
CLEAN_MODEL_PATH = os.path.join(OUT_DIR, "best_noopt.keras")
METRICS_PATH     = os.path.join(OUT_DIR, "metrics.json")

LOSS_PNG = os.path.join(PLOTS_DIR, "loss_train_vs_val.png")
ACC_PNG  = os.path.join(PLOTS_DIR, "acc_train_vs_val.png")
CM_PNG   = os.path.join(PLOTS_DIR, "confusion_matrix.png")

TFLITE_FP32_PATH = os.path.join(OUT_DIR, "best_fp32.tflite")
TFLITE_DRQ_PATH  = os.path.join(OUT_DIR, "best_dynamic_range.tflite")
TFLITE_INT8_PATH = os.path.join(OUT_DIR, "best_int8.tflite")
LABELS_TXT       = os.path.join(OUT_DIR, "labels.txt")

np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# ============================================================
# SECTION 2: TPU / STRATEGY INIT
# ============================================================
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
    print("TPU:", tpu.master())
except Exception as e:
    strategy = tf.distribute.get_strategy()
    print("TPU not used. Fallback strategy. Reason:", e)

print("Strategy:", type(strategy).__name__)
print("Replicas:", strategy.num_replicas_in_sync)

NUM_REPLICAS = strategy.num_replicas_in_sync
GLOBAL_BATCH = BATCH_PER_REPLICA * NUM_REPLICAS
print("GLOBAL_BATCH:", GLOBAL_BATCH)
# Out:
# TPU not used. Fallback strategy. Reason: Please provide a TPU Name to connect to.
# Strategy: _DefaultDistributionStrategy
# Replicas: 1
# GLOBAL_BATCH: 32

# %%
# ============================================================
# SECTION 3: DATA HELPERS
# ============================================================
def list_files(dataset_dir):
    p = pathlib.Path(dataset_dir)
    classes = sorted([d.name for d in p.iterdir() if d.is_dir()])
    paths, labels = [], []
    for i, c in enumerate(classes):
        for x in (p / c).glob("*"):
            if x.suffix.lower() in [".jpg", ".jpeg", ".png"]:
                paths.append(str(x))
                labels.append(i)
    return np.array(paths), np.array(labels), classes

def decode_resize(path, label):
    img_bytes = tf.io.read_file(path)
    is_jpeg = tf.strings.regex_full_match(tf.strings.lower(path), ".*\\.jpe?g")
    img = tf.cond(
        is_jpeg,
        lambda: tf.image.decode_jpeg(img_bytes, channels=3),
        lambda: tf.image.decode_png(img_bytes, channels=3),
    )
    img = tf.image.resize(img, IMG_SIZE)
    img = tf.cast(img, tf.float32)
    img = preprocess_input(img)   # NASNetMobile preprocess
    return img, label

def augment(img, label):
    img = tf.image.random_flip_left_right(img)
    img = tf.image.random_brightness(img, 0.08)
    img = tf.image.random_contrast(img, 0.9, 1.1)
    k = tf.random.uniform([], 0, 4, dtype=tf.int32)
    img = tf.image.rot90(img, k)
    return img, label

def make_ds(paths, labels, train=False):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    if train:
        ds = ds.shuffle(buffer_size=len(paths), seed=SEED, reshuffle_each_iteration=True)
    ds = ds.map(decode_resize, num_parallel_calls=AUTOTUNE)
    if train:
        ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
    ds = ds.batch(GLOBAL_BATCH, drop_remainder=train).prefetch(AUTOTUNE)
    return ds

def oversample(paths, labels):
    rng = np.random.RandomState(SEED)
    cls, cnt = np.unique(labels, return_counts=True)
    m = cnt.max()
    new_p, new_y = [], []
    for c in cls:
        idx = np.where(labels == c)[0]
        chosen = rng.choice(idx, size=m, replace=True)
        new_p.extend(paths[chosen].tolist())
        new_y.extend([c] * m)
    perm = rng.permutation(len(new_p))
    return np.array(new_p)[perm], np.array(new_y)[perm]

# %%
# ============================================================
# SECTION 4: MODEL (NASNetMobile)
# ============================================================
def focal_loss(num_classes, gamma=FOCAL_GAMMA, alpha=FOCAL_ALPHA):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.int32)
        y_one = tf.one_hot(y_true, depth=num_classes)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
        ce = -y_one * tf.math.log(y_pred)
        w = alpha * tf.math.pow(1 - y_pred, gamma)
        return tf.reduce_sum(w * ce, axis=1)
    return loss


    # ============================================================
# SECTION 4: MODEL (NASNetMobile - no alpha)
# ============================================================
def build_model(num_classes):
    base = NASNetMobile(
        input_shape=IMG_SIZE + (3,),
        include_top=False,
        weights="imagenet"
    )
    base.trainable = False

    inp = layers.Input(shape=IMG_SIZE + (3,))
    x = base(inp, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    out = layers.Dense(num_classes, activation="softmax")(x)
    return models.Model(inp, out), base


def compile_model(model, num_classes, lr):
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss=focal_loss(num_classes),
        metrics=["accuracy"],
    )

def fine_tune(base, ratio=FINE_TUNE_RATIO):
    base.trainable = True
    n = len(base.layers)
    fine_at = int(n * ratio)
    for i, layer in enumerate(base.layers):
        layer.trainable = (i >= fine_at)

# %%
# ============================================================
# SECTION 5: EVAL + PLOTS
# ============================================================
def eval_metrics(model, ds, class_names):
    y_true, y_pred = [], []
    for x, y in ds:
        p = model.predict(x, verbose=0)
        y_true.extend(y.numpy().tolist())
        y_pred.extend(np.argmax(p, axis=1).tolist())

    rep = classification_report(
        y_true, y_pred, target_names=class_names, output_dict=True, zero_division=0
    )
    acc = rep["accuracy"]
    prec = np.mean([rep[c]["precision"] for c in class_names])
    rec  = np.mean([rep[c]["recall"] for c in class_names])
    f1   = np.mean([rep[c]["f1-score"] for c in class_names])
    return acc, prec, rec, f1

def get_preds(model, ds):
    y_true, y_pred = [], []
    for x, y in ds:
        p = model.predict(x, verbose=0)
        y_true.extend(y.numpy().tolist())
        y_pred.extend(np.argmax(p, axis=1).tolist())
    return np.array(y_true), np.array(y_pred)

def save_train_val_plots(h1, h2, loss_path, acc_path):
    def cat(k):
        return list(h1.history.get(k, [])) + list(h2.history.get(k, []))

    tr_loss = cat("loss")
    va_loss = cat("val_loss")
    tr_acc  = cat("accuracy")
    va_acc  = cat("val_accuracy")
    epochs  = np.arange(1, len(tr_loss) + 1)

    plt.figure()
    plt.plot(epochs, tr_loss, label="train_loss")
    plt.plot(epochs, va_loss, label="val_loss")
    plt.xlabel("Epoch"); plt.ylabel("Loss")
    plt.title("Training vs Validation Loss")
    plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(loss_path, dpi=200)
    plt.close()

    plt.figure()
    plt.plot(epochs, tr_acc, label="train_acc")
    plt.plot(epochs, va_acc, label="val_acc")
    plt.xlabel("Epoch"); plt.ylabel("Accuracy")
    plt.title("Training vs Validation Accuracy")
    plt.legend(); plt.grid(True)
    plt.tight_layout()
    plt.savefig(acc_path, dpi=200)
    plt.close()

def save_confusion_matrix_png(y_true, y_pred, class_names, out_path, normalize=False):
    cm = confusion_matrix(y_true, y_pred, labels=np.arange(len(class_names)))

    if normalize:
        cm = cm.astype("float32") / np.maximum(cm.sum(axis=1, keepdims=True), 1e-9)

    plt.figure(figsize=(8, 8))
    vmax = 1.0 if normalize else cm.max()
    plt.imshow(cm, cmap="Blues", vmin=0.0, vmax=vmax)

    plt.title("Confusion Matrix" + (" (Normalized)" if normalize else ""))
    plt.colorbar()

    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45, ha="right")
    plt.yticks(tick_marks, class_names)

    fmt = ".2f" if normalize else "d"
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), ha="center", va="center", color="black")

    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.tight_layout()
    plt.savefig(out_path, dpi=200)
    plt.close()

# %%
# ============================================================
# SECTION 6: RUN (CV + FINAL TRAIN + TEST)
# ============================================================
paths, labels, class_names = list_files(DATASET_DIR)
num_classes = len(class_names)

print("Classes:", class_names)
print("Num classes:", num_classes)

# Optional sanity check: your expected dataset count
# You said 998/998/997/997 => total 3990
print("Total images found:", len(paths))
for i, c in enumerate(class_names):
    print(c, ":", int(np.sum(labels == i)))

# Split: Train vs Test (TEST never touched in CV/training decisions)
train_p, test_p, train_y, test_y = train_test_split(
    paths, labels, test_size=TEST_SIZE, random_state=SEED, stratify=labels
)

# -----------------------
# CV on TRAIN only
# -----------------------
skf = StratifiedKFold(n_splits=KFOLDS, shuffle=True, random_state=SEED)
cv_acc = []

for fold, (tr, va) in enumerate(skf.split(train_p, train_y), start=1):
    tr_p, tr_l = train_p[tr], train_y[tr]
    va_p, va_l = train_p[va], train_y[va]

    tr_p2, tr_l2 = oversample(tr_p, tr_l)
    tr_ds = make_ds(tr_p2, tr_l2, train=True)
    va_ds = make_ds(va_p, va_l, train=False)

    with strategy.scope():
        model, base = build_model(num_classes)
        compile_model(model, num_classes, LR_HEAD)

    cb_cv = [
        callbacks.EarlyStopping(monitor="val_loss", patience=CV_PATIENCE, restore_best_weights=True),
        callbacks.ReduceLROnPlateau(monitor="val_loss", factor=REDUCE_LR_FACTOR, patience=1),
    ]

    model.fit(tr_ds, validation_data=va_ds, epochs=EPOCHS_HEAD, verbose=1, callbacks=cb_cv)

    with strategy.scope():
        fine_tune(base, ratio=FINE_TUNE_RATIO)
        compile_model(model, num_classes, LR_FINE)

    model.fit(tr_ds, validation_data=va_ds, epochs=EPOCHS_FINE, verbose=1, callbacks=cb_cv)

    acc, _, _, _ = eval_metrics(model, va_ds, class_names)
    cv_acc.append(acc)
    print(f"Fold {fold} val accuracy: {acc:.4f}")

cv_mean, cv_std = float(np.mean(cv_acc)), float(np.std(cv_acc))
print(f"\nCV Accuracy (mean ± std): {cv_mean:.4f} ± {cv_std:.4f}")

# -----------------------
# Final Train/Val split from TRAIN only
# -----------------------
final_tr_p, final_va_p, final_tr_y, final_va_y = train_test_split(
    train_p, train_y, test_size=FINAL_VAL_SIZE, random_state=SEED, stratify=train_y
)

final_tr_p2, final_tr_y2 = oversample(final_tr_p, final_tr_y)
final_tr_ds = make_ds(final_tr_p2, final_tr_y2, train=True)
final_va_ds = make_ds(final_va_p, final_va_y, train=False)
test_ds     = make_ds(test_p, test_y, train=False)

# -----------------------
# Final training + checkpoint
# -----------------------
with strategy.scope():
    model, base = build_model(num_classes)
    compile_model(model, num_classes, LR_HEAD)

ckpt = callbacks.ModelCheckpoint(MODEL_PATH, monitor="val_accuracy", save_best_only=True, verbose=1)
cb_final = [
    ckpt,
    callbacks.EarlyStopping(monitor="val_loss", patience=FINAL_PATIENCE, restore_best_weights=True),
    callbacks.ReduceLROnPlateau(monitor="val_loss", factor=REDUCE_LR_FACTOR, patience=1),
]

h1 = model.fit(final_tr_ds, validation_data=final_va_ds, epochs=EPOCHS_HEAD, verbose=1, callbacks=cb_final)

with strategy.scope():
    fine_tune(base, ratio=FINE_TUNE_RATIO)
    compile_model(model, num_classes, LR_FINE)

h2 = model.fit(final_tr_ds, validation_data=final_va_ds, epochs=EPOCHS_FINE, verbose=1, callbacks=cb_final)

# Load best + save clean model (no optimizer)
best = tf.keras.models.load_model(MODEL_PATH, compile=False)
best.save(CLEAN_MODEL_PATH, include_optimizer=False)

# Save plots
save_train_val_plots(h1, h2, LOSS_PNG, ACC_PNG)

# Test evaluation
test_acc, test_prec, test_rec, test_f1 = eval_metrics(best, test_ds, class_names)

# Confusion matrix (normalized)
y_true, y_pred = get_preds(best, test_ds)
save_confusion_matrix_png(y_true, y_pred, class_names, CM_PNG, normalize=True)

# Model size
train_model_size_mb = os.path.getsize(MODEL_PATH) / (1024 * 1024)
clean_model_size_mb = os.path.getsize(CLEAN_MODEL_PATH) / (1024 * 1024)
# Out:
# Classes: ['Biological', 'Metal', 'Paper', 'Plastic']
# Num classes: 4
# Total images found: 3986
# Biological : 997
# Metal : 997
# Paper : 996
# Plastic : 996
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 331s 5s/step - accuracy: 0.4132 - loss: 0.8533 - val_accuracy: 0.8935 - val_loss: 0.1515 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 185s 3s/step - accuracy: 0.8257 - loss: 0.2292 - val_accuracy: 0.9194 - val_loss: 0.1074 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 163s 3s/step - accuracy: 0.8680 - loss: 0.1718 - val_accuracy: 0.9140 - val_loss: 0.1058 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 191s 3s/step - accuracy: 0.8878 - loss: 0.1433 - val_accuracy: 0.9301 - val_loss: 0.0889 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 203s 3s/step - accuracy: 0.9017 - loss: 0.1217 - val_accuracy: 0.9376 - val_loss: 0.0831 - learning_rate: 0.0010
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 253s 4s/step - accuracy: 0.8221 - loss: 0.2111 - val_accuracy: 0.9376 - val_loss: 0.0809 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 190s 3s/step - accuracy: 0.7989 - loss: 0.2363 - val_accuracy: 0.9355 - val_loss: 0.0801 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - accuracy: 0.8342 - loss: 0.1807 - val_accuracy: 0.9355 - val_loss: 0.0789 - learning_rate: 1.0000e-05
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 208s 4s/step - accuracy: 0.8438 - loss: 0.1715 - val_accuracy: 0.9376 - val_loss: 0.0781 - learning_rate: 1.0000e-05
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 176s 3s/step - accuracy: 0.8907 - loss: 0.1178 - val_accuracy: 0.9387 - val_loss: 0.0772 - learning_rate: 1.0000e-05
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 179s 3s/step - accuracy: 0.8930 - loss: 0.1139 - val_accuracy: 0.9387 - val_loss: 0.0762 - learning_rate: 1.0000e-05
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 178s 3s/step - accuracy: 0.9171 - loss: 0.1132 - val_accuracy: 0.9366 - val_loss: 0.0760 - learning_rate: 1.0000e-05
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 202s 3s/step - accuracy: 0.9124 - loss: 0.0908 - val_accuracy: 0.9387 - val_loss: 0.0750 - learning_rate: 1.0000e-05
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 207s 4s/step - accuracy: 0.9049 - loss: 0.1047 - val_accuracy: 0.9409 - val_loss: 0.0741 - learning_rate: 1.0000e-05
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 208s 4s/step - accuracy: 0.9212 - loss: 0.0885 - val_accuracy: 0.9430 - val_loss: 0.0727 - learning_rate: 1.0000e-05
# Fold 1 val accuracy: 0.9430
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 210s 3s/step - accuracy: 0.4828 - loss: 0.7173 - val_accuracy: 0.8774 - val_loss: 0.1595 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 185s 3s/step - accuracy: 0.8167 - loss: 0.2322 - val_accuracy: 0.9032 - val_loss: 0.1208 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 154s 3s/step - accuracy: 0.8690 - loss: 0.1720 - val_accuracy: 0.9151 - val_loss: 0.1119 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 185s 3s/step - accuracy: 0.8965 - loss: 0.1229 - val_accuracy: 0.9194 - val_loss: 0.1006 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - accuracy: 0.8924 - loss: 0.1282 - val_accuracy: 0.9280 - val_loss: 0.0968 - learning_rate: 0.0010
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 252s 4s/step - accuracy: 0.7965 - loss: 0.2287 - val_accuracy: 0.9333 - val_loss: 0.0926 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 178s 3s/step - accuracy: 0.8455 - loss: 0.1770 - val_accuracy: 0.9344 - val_loss: 0.0901 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 211s 4s/step - accuracy: 0.8529 - loss: 0.1643 - val_accuracy: 0.9376 - val_loss: 0.0883 - learning_rate: 1.0000e-05
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 207s 4s/step - accuracy: 0.8744 - loss: 0.1435 - val_accuracy: 0.9387 - val_loss: 0.0866 - learning_rate: 1.0000e-05
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 208s 4s/step - accuracy: 0.8852 - loss: 0.1305 - val_accuracy: 0.9387 - val_loss: 0.0847 - learning_rate: 1.0000e-05
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 180s 3s/step - accuracy: 0.8971 - loss: 0.1170 - val_accuracy: 0.9398 - val_loss: 0.0841 - learning_rate: 1.0000e-05
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 213s 4s/step - accuracy: 0.9205 - loss: 0.1015 - val_accuracy: 0.9398 - val_loss: 0.0830 - learning_rate: 1.0000e-05
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 212s 4s/step - accuracy: 0.9024 - loss: 0.1126 - val_accuracy: 0.9409 - val_loss: 0.0816 - learning_rate: 1.0000e-05
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 208s 4s/step - accuracy: 0.9207 - loss: 0.1000 - val_accuracy: 0.9419 - val_loss: 0.0805 - learning_rate: 1.0000e-05
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 212s 4s/step - accuracy: 0.9144 - loss: 0.0946 - val_accuracy: 0.9430 - val_loss: 0.0795 - learning_rate: 1.0000e-05
# Fold 2 val accuracy: 0.9430
# Epoch 1/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - accuracy: 0.4595 - loss: 0.8045 - val_accuracy: 0.8925 - val_loss: 0.1422 - learning_rate: 0.0010
# Epoch 2/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 164s 3s/step - accuracy: 0.7828 - loss: 0.2600 - val_accuracy: 0.9226 - val_loss: 0.1034 - learning_rate: 0.0010
# Epoch 3/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 187s 3s/step - accuracy: 0.8353 - loss: 0.1882 - val_accuracy: 0.9323 - val_loss: 0.0938 - learning_rate: 0.0010
# Epoch 4/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 177s 3s/step - accuracy: 0.8695 - loss: 0.1576 - val_accuracy: 0.9323 - val_loss: 0.0909 - learning_rate: 0.0010
# Epoch 5/5
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 136s 2s/step - accuracy: 0.8974 - loss: 0.1308 - val_accuracy: 0.9355 - val_loss: 0.0858 - learning_rate: 0.0010
# Epoch 1/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 229s 3s/step - accuracy: 0.7649 - loss: 0.2740 - val_accuracy: 0.9344 - val_loss: 0.0832 - learning_rate: 1.0000e-05
# Epoch 2/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 191s 3s/step - accuracy: 0.8077 - loss: 0.2296 - val_accuracy: 0.9344 - val_loss: 0.0823 - learning_rate: 1.0000e-05
# Epoch 3/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 203s 4s/step - accuracy: 0.8502 - loss: 0.1746 - val_accuracy: 0.9355 - val_loss: 0.0815 - learning_rate: 1.0000e-05
# Epoch 4/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - accuracy: 0.8739 - loss: 0.1520 - val_accuracy: 0.9366 - val_loss: 0.0798 - learning_rate: 1.0000e-05
# Epoch 5/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 204s 4s/step - accuracy: 0.8662 - loss: 0.1439 - val_accuracy: 0.9366 - val_loss: 0.0788 - learning_rate: 1.0000e-05
# Epoch 6/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 174s 3s/step - accuracy: 0.8738 - loss: 0.1505 - val_accuracy: 0.9387 - val_loss: 0.0778 - learning_rate: 1.0000e-05
# Epoch 7/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 194s 3s/step - accuracy: 0.8930 - loss: 0.1244 - val_accuracy: 0.9409 - val_loss: 0.0768 - learning_rate: 1.0000e-05
# Epoch 8/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 210s 4s/step - accuracy: 0.8955 - loss: 0.1105 - val_accuracy: 0.9398 - val_loss: 0.0755 - learning_rate: 1.0000e-05
# Epoch 9/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 197s 3s/step - accuracy: 0.8972 - loss: 0.1076 - val_accuracy: 0.9387 - val_loss: 0.0746 - learning_rate: 1.0000e-05
# Epoch 10/10
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 209s 4s/step - accuracy: 0.9100 - loss: 0.1026 - val_accuracy: 0.9398 - val_loss: 0.0740 - learning_rate: 1.0000e-05
# Fold 3 val accuracy: 0.9398
#
# CV Accuracy (mean ± std): 0.9419 ± 0.0015
# Epoch 1/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4433 - loss: 0.8640
# Epoch 1: val_accuracy improved from -inf to 0.90453, saving model to /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 186s 2s/step - accuracy: 0.4458 - loss: 0.8595 - val_accuracy: 0.9045 - val_loss: 0.1503 - learning_rate: 0.0010
# Epoch 2/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8248 - loss: 0.2405
# Epoch 2: val_accuracy improved from 0.90453 to 0.91169, saving model to /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.8250 - loss: 0.2401 - val_accuracy: 0.9117 - val_loss: 0.1144 - learning_rate: 0.0010
# Epoch 3/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8713 - loss: 0.1545
# Epoch 3: val_accuracy improved from 0.91169 to 0.92363, saving model to /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.8713 - loss: 0.1545 - val_accuracy: 0.9236 - val_loss: 0.1099 - learning_rate: 0.0010
# Epoch 4/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8899 - loss: 0.1338
# Epoch 4: val_accuracy did not improve from 0.92363
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 135s 2s/step - accuracy: 0.8900 - loss: 0.1337 - val_accuracy: 0.9236 - val_loss: 0.1030 - learning_rate: 0.0010
# Epoch 5/5
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8872 - loss: 0.1236
# Epoch 5: val_accuracy improved from 0.92363 to 0.93079, saving model to /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 158s 2s/step - accuracy: 0.8873 - loss: 0.1234 - val_accuracy: 0.9308 - val_loss: 0.1045 - learning_rate: 0.0010
# Epoch 1/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7505 - loss: 0.2877
# Epoch 1: val_accuracy did not improve from 0.93079
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 205s 2s/step - accuracy: 0.7508 - loss: 0.2873 - val_accuracy: 0.9236 - val_loss: 0.0983 - learning_rate: 1.0000e-05
# Epoch 2/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8413 - loss: 0.1971
# Epoch 2: val_accuracy did not improve from 0.93079
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 182s 2s/step - accuracy: 0.8414 - loss: 0.1969 - val_accuracy: 0.9284 - val_loss: 0.0953 - learning_rate: 1.0000e-05
# Epoch 3/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8605 - loss: 0.1630
# Epoch 3: val_accuracy improved from 0.93079 to 0.93317, saving model to /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.8607 - loss: 0.1629 - val_accuracy: 0.9332 - val_loss: 0.0917 - learning_rate: 1.0000e-05
# Epoch 4/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8758 - loss: 0.1514
# Epoch 4: val_accuracy did not improve from 0.93317
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.8759 - loss: 0.1513 - val_accuracy: 0.9332 - val_loss: 0.0903 - learning_rate: 1.0000e-05
# Epoch 5/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9009 - loss: 0.1297
# Epoch 5: val_accuracy did not improve from 0.93317
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 181s 2s/step - accuracy: 0.9009 - loss: 0.1296 - val_accuracy: 0.9332 - val_loss: 0.0880 - learning_rate: 1.0000e-05
# Epoch 6/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9129 - loss: 0.1091
# Epoch 6: val_accuracy improved from 0.93317 to 0.93556, saving model to /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.9128 - loss: 0.1092 - val_accuracy: 0.9356 - val_loss: 0.0865 - learning_rate: 1.0000e-05
# Epoch 7/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9216 - loss: 0.0868
# Epoch 7: val_accuracy improved from 0.93556 to 0.94272, saving model to /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 226s 3s/step - accuracy: 0.9215 - loss: 0.0869 - val_accuracy: 0.9427 - val_loss: 0.0852 - learning_rate: 1.0000e-05
# Epoch 8/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9089 - loss: 0.0943
# Epoch 8: val_accuracy did not improve from 0.94272
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.9089 - loss: 0.0944 - val_accuracy: 0.9427 - val_loss: 0.0849 - learning_rate: 1.0000e-05
# Epoch 9/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9127 - loss: 0.1050
# Epoch 9: val_accuracy did not improve from 0.94272
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.9126 - loss: 0.1050 - val_accuracy: 0.9427 - val_loss: 0.0821 - learning_rate: 1.0000e-05
# Epoch 10/10
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9154 - loss: 0.0873
# Epoch 10: val_accuracy improved from 0.94272 to 0.94511, saving model to /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best.keras
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9154 - loss: 0.0874 - val_accuracy: 0.9451 - val_loss: 0.0805 - learning_rate: 1.0000e-05

# %%
# ============================================================
# SECTION 7: BENCHMARK + METRICS JSON
# ============================================================
def benchmark_warm(model, warmup=WARMUP_RUNS, runs=BENCH_RUNS):
    x1 = np.random.rand(1, *IMG_SIZE, 3).astype("float32")
    xb = np.random.rand(GLOBAL_BATCH, *IMG_SIZE, 3).astype("float32")

    for _ in range(warmup):
        _ = model.predict(x1, verbose=0)

    t0 = time.time()
    for _ in range(runs):
        _ = model.predict(x1, verbose=0)
    single_ms = ((time.time() - t0) / runs) * 1000

    for _ in range(warmup):
        _ = model.predict(xb, verbose=0)

    t0 = time.time()
    for _ in range(runs):
        _ = model.predict(xb, verbose=0)
    total = time.time() - t0

    thr = (GLOBAL_BATCH * runs) / total
    eff_ms = 1000.0 / thr
    return single_ms, thr, eff_ms

single_ms, thr, eff_ms = benchmark_warm(best, warmup=WARMUP_RUNS, runs=BENCH_RUNS)
params = int(best.count_params())

out = {
    "model": "NASNetMobile(alpha=1.0)",
    "classes": class_names,
    "strategy": type(strategy).__name__,
    "replicas": int(NUM_REPLICAS),
    "global_batch": int(GLOBAL_BATCH),
    "cv_accuracy_mean": cv_mean,
    "cv_accuracy_std": cv_std,
    "test_accuracy": float(test_acc),
    "precision_macro": float(test_prec),
    "recall_macro": float(test_rec),
    "f1_macro": float(test_f1),
    "parameters": params,
    "model_size_mb_training_checkpoint": float(train_model_size_mb),
    "model_size_mb_clean_inference": float(clean_model_size_mb),
    "single_image_latency_ms_after_warmup": float(single_ms),
    "throughput_images_per_sec": float(thr),
    "effective_ms_per_image_from_throughput": float(eff_ms),
    "loss_plot_path": LOSS_PNG,
    "accuracy_plot_path": ACC_PNG,
    "confusion_matrix_plot_path": CM_PNG,
}

with open(METRICS_PATH, "w") as f:
    json.dump(out, f, indent=2)

print("\nSaved training checkpoint:", MODEL_PATH)
print("Saved clean inference model:", CLEAN_MODEL_PATH)
print("Saved loss plot:", LOSS_PNG)
print("Saved accuracy plot:", ACC_PNG)
print("Saved confusion matrix:", CM_PNG)
print("Metrics:", METRICS_PATH)
# Out:
# Saved training checkpoint: /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best.keras
# Saved clean inference model: /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best_noopt.keras
# Saved loss plot: /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/plots/loss_train_vs_val.png
# Saved accuracy plot: /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/plots/acc_train_vs_val.png
# Saved confusion matrix: /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/plots/confusion_matrix.png
# Metrics: /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/metrics.json

# %%
# ============================================================
# SECTION 8: TFLite EXPORT
# ============================================================
with open(LABELS_TXT, "w") as f:
    for name in class_names:
        f.write(name + "\n")
print("Saved labels:", LABELS_TXT)

clean = tf.keras.models.load_model(CLEAN_MODEL_PATH, compile=False)

# FP32
converter = tf.lite.TFLiteConverter.from_keras_model(clean)
tflite_fp32 = converter.convert()
with open(TFLITE_FP32_PATH, "wb") as f:
    f.write(tflite_fp32)
print("Saved TFLite FP32:", TFLITE_FP32_PATH)

# Dynamic Range Quant
converter = tf.lite.TFLiteConverter.from_keras_model(clean)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_drq = converter.convert()
with open(TFLITE_DRQ_PATH, "wb") as f:
    f.write(tflite_drq)
print("Saved TFLite Dynamic Range:", TFLITE_DRQ_PATH)

# INT8
def rep_data_gen():
    for x, _ in final_tr_ds.take(REP_BATCHES):
        yield [tf.cast(x, tf.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(clean)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = rep_data_gen
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8
converter.inference_output_type = tf.int8

try:
    tflite_int8 = converter.convert()
    with open(TFLITE_INT8_PATH, "wb") as f:
        f.write(tflite_int8)
    print("Saved TFLite INT8:", TFLITE_INT8_PATH)
except Exception as e:
    print("INT8 conversion failed. Reason:", e)
    print("Tip: remove int8 input/output lines for hybrid quantization and try again.")
# Out:
# Saved labels: /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/labels.txt
# Saved artifact at '/tmp/tmp_6h8gciy'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer_7')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   139742640961296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640957072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640962640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640958800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640960912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640962256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640961104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640960144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640960720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640960336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640961872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640962832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640963216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640963024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779393808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779394000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779393424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779393616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640956880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779392656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640958224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742640960528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779394960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779395152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779392848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779394384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779394576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779394768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779394192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779395536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779396112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779396304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779395728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779395920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779395344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779396688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779398416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779398608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779397264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779397840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779396880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779397072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779393232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779397456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779399568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779399760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779399184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779399376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779398032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779398224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779397648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779398992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779398800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779400144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779401872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779402064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779400720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779401296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779400336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779400528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779396496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779400912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779403024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779403216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779402640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779402832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779401488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779401680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779401104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779402448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779402256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139743937591056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779404368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779405136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779405328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779393040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779404944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779403408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779403792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779392080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779404752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779406288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779406480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779392464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779405712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779407440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779407632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779407056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779407248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779405904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779406096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779405520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779406864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779407824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779408208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779406672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779408016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779399952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779403600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779404176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779392272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778261968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778263120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742779404560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778262544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778262928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778263504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778265232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778265424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778264080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778264656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778263696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778263888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778262736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778264272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778266384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778266576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778266000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778266192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778264848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778265040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778264464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778265808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778265616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778266960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778268688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778268880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778267536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778268112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778267152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778267344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778263312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778267728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778269840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778270032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778269456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778269648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778268304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778268496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778267920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778269264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778269072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778270416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778271184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778270224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778270800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778262352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778271568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778271952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778272144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778270992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778271760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778274256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778274448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778273872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778274064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778273488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778273680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778273104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778273296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778271376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778272528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778261776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778272336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778277328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778277520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778276944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778277136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778276560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778276752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778276176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778276368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778275792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778275984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778275408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778275600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778275024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778275216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778272720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778272912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778270608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778274832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777149584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777149776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777149200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777149392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778261584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777147664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778274640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778277712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778262160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742778266768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777153040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777153232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777152656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777152848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777151504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777151696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777151120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777151312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777152272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777152464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777151888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777152080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777148816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777149008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777148240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777150160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777150736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777150928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777150352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777150544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777153616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777149968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777148048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777154192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777147472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777154576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777154960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777155152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777147856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777154768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777157264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777157456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777156880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777157072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777156496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777156688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777156112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777156304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777154384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777155536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777160720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777160912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777160336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777160528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777159952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777160144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777159568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777159760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777159184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777159376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777158800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777158992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777158416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777158608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777158032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777158224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777155728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777155920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777153424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777157840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777163024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777163216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777162640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777162832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777162256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777162448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777161872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777162064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777157648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777161296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775872208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775872400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775871824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775872016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775870672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775870864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777148432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777161104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775871440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775871632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775871056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775871248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777161488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777163408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777155344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777163600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777154000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777153808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777148624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742777161680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775872784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775869520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775869904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775873360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775869712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775873744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775874128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775874320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775870096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775873936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775876432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775876624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775876048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775876240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775875664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775875856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775875280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775875472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775873552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775874704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775879888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775880080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775879504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775879696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775879120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775879312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775878736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775878928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775878352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775878544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775877968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775878160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775877584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775877776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775877200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775877392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775874896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775875088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775872592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775877008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775882192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775882384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775881808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775882000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775881424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775881616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775881040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775881232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775876816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775880464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775870288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775880272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775885264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775885456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775884112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775884304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775883728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775883920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775884880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775885072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775884496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775884688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775880656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775880848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775874512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775882768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775883344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775883536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775882960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775883152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775873168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775872976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775882576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774739024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775870480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742775885648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774740752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774740944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774739984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774740560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774743056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774743248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774742672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774742864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774742288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774742480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774741904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774742096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774739216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774741328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774746512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774746704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774746128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774746320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774745744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774745936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774745360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774745552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774744976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774745168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774744592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774744784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774744208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774744400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774743824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774744016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774741520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774741712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774740368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774743632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774748816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774749008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774748432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774748624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774748048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774748240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774747664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774747856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774743440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774747088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774752272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774752464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774751888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774752080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774750736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774750928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774750352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774750544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774751504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774751696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774751120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774751312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774747280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774747472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774741136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774749392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774749968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774750160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774749584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774749776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774752848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774749200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774754192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774754384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774739408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774754000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774740176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774753424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774746896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774753808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774754576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774755152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774753616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774754768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773544144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773544336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774753232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774752656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774753040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774754960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774739792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742774739600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773545296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773545488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773542992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773544720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773544912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773545104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773544528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773545872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773546448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773546640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773546064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773546256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773545680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773547024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773548752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773548944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773547600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773548176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773547216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773547408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773543184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773547792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773549904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773550096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773549520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773549712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773548368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773548560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773547984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773549328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773549136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773550480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773552208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773552400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773551056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773551632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773550672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773550864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773546832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773551248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773553360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773553552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773552976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773553168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773551824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773552016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773551440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773552784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773552592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773553936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773554704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773553744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773554320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773543376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773555088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773555472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773555664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773554512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773555280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773557776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773557968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773557392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773557584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773557008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773557200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773556624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773556816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773554896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773556048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772463568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772463760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772463184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772463376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772462800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772462992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773543760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773555856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773550288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773543568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773543952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773559120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773558928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773558160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773558544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773558736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773556240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773556432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773554128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773558352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772465872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772466064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772465488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772465680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772465104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772465296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772464720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772464912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772461648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772464144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772469328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772469520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772468944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772469136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772467792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772467984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772467408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772467600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772468560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772468752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772468176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772468368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772464336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772464528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772461840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772466448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772467024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772467216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772466640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772466832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772469904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772466256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772462224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772470480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772463952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772470864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772471248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772471440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772462032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772471056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772473552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772473744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772473168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772473360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772472784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772472976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772472400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772472592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772470672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772471824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772477008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772477200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772476624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772476816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772476240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772476432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772475856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772476048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772475472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772475664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772475088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772475280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772474704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772474896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772474320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772474512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772472016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772472208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772469712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772474128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772470288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773362768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772471632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772470096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772462608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772462416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772477392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772477776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772473936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742772477584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773367568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773367760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773367184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773367376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773366032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773366224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773365648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773365840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773366800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773366992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773366416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773366608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773363728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773363536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773363152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773364688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773365264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773365456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773364880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773365072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773368144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773364496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773363344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773368720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773362960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773369104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773369488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773369680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773364304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773369296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773371792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773371984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773371408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773371600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773371024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773371216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773370640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773370832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773368912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773370064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773375248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773375440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773374864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773375056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773374480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773374672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773374096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773374288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773373712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773373904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773373328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773373520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773372944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773373136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773372560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773372752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773370256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773370448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773367952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773372368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773377552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773377744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773377168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773377360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773376784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773376976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742773376400: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
#   139742729036688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729036880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729036304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729036496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729032464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729032656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729029008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729034576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729035152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729035344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729034768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729034960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729038032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729034384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729028240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729038608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729032080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729038992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729039376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729039568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729028432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729039184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729041680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729041872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729041296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729041488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729040912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729041104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729040528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729040720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729038800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729039952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727750672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727750096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729027664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729039760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729038224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729038416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729027856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729043792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729043600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729042064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729043216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729043408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729042832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729043024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729042448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729042640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729040144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729040336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729037840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742729042256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727753168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727753360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727752784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727752976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727752400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727752592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727752016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727752208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727749712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727751440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727756624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727756816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727756240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727756432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727755088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727755280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727754704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727754896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727755856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727756048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727755472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727755664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727751632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727751824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727749904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727753744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727754320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727754512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727753936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727754128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727757200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727753552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727750480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727757776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727751248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727758160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727758544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727758736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727750288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727758352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727760848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727761040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727760464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727760656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727760080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727760272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727759696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727759888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727757968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727759120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727764304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727764496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727763920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727764112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727763536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727763728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727763152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727763344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727762768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727762960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727762384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727762576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727762000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727762192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727761616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727761808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727759312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727759504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727757008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727761424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727750864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727765072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727751056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727765264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727765840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727757584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727765456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727765648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727761232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727764880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726574096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726574288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726573712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726573904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726572560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726572752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726572176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726572368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726573328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726573520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726572944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726573136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727758928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726571216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727757392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742727764688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726571792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726571984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726571408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726571600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726574672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726570832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726570640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726575248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726571024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726575632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726576016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726576208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726570448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726575824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726578320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726578512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726577936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726578128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726577552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726577744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726577168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726577360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726575440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726576592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726581776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726581968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726581392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726581584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726581008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726581200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726580624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726580816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726580240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726580432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726579856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726580048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726579472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726579664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726579088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726579280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726576784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726576976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726574480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726578896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726584080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726584272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726583696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726583888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726583312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726583504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726582928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726583120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726578704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726582352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742725342416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742725342608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726570064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726582160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726586000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726584464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726585616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726585808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726575056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726574864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726570256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726586192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726582544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726582736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726576400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726584656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726585232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726585424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726584848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742726585040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742725342992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139742725342224: TensorSpec(shape=(), dtype=tf.resource, name=None)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/convert.py:854: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn(
# Saved TFLite INT8: /content/drive/MyDrive/ImageClassification/OUT_NASNetMobile/best_int8.tflite
